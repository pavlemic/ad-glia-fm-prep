# %% [markdown]
# # colab_08 — Astrocyte subset: colab_05 verdict application, sub-clustering, and substate definition
#
# Carries the **astrocyte** half of the colab_05 glia subset forward — the parallel of colab_07 for the other lineage. colab_05 gave the astrocytes a full six-lever residual-batch adjudication and left per-cluster verdicts (**cl22 = ambient**, **cl33 = real_confounded (keep)**, **cl42 / cl45 = donor_effect**) but never defined astrocyte **substate** labels. This notebook (1) applies those colab_05 cluster verdicts to the ca. 94,271 astrocytes — dropping the ambient / donor-effect technical clusters *before* anything downstream, so a technical pocket cannot seed its own substate subcluster (the cl44 lesson from colab_07); (2) sub-clusters the remaining astrocytes on the scVI latent to expose substate structure; (3) defines pre-committed **reactive / DAA (GFAP-high) vs resting** substate labels that **eval #1** consumes; and (4) runs the same lighter per-subcluster integrity scan as colab_07. Runs on standard runtime + **high-RAM** (loads the ca. 6.5 GB glia object); no GPU — there is no model training here.
#
# **Two design points were flagged as provisional going into the first run; both resolved without needing a rebuild.** The cl42/cl45 drop-vs-keep call (§4a) was kept as scaffolded. The reactive-vs-resting gene lists (§6a) needed no panel change — the z-scored continuous-axis method avoided the argmax collapse that hit microglia "DAM" in colab_07 — but one listed gene (SERPINA3) turned out to be absent from the cross-study gene intersection entirely (§6a addendum), and the reactive bucket showed a donor/study confound more extensive than colab_07's microglia precedent (§6b–§6d). See each section's interpretation cell for what was found and decided.

# %% [markdown]
# ## 1 — Setup

# %% [markdown]
# ### 1a — Mount Drive + clone/pull repo + install env
#
# Same pattern as colab_04–07: mount Drive, clone-or-pull the repo, pin numpy first, install the integration env, and add an explicit `leidenalg` install (the §5 Leiden sub-clustering) in case it is not pinned in `requirements_integration.txt`. No GPU is requested — sub-clustering, scoring and DE are CPU work; the only heavy resource is RAM for the ca. 6.5 GB glia object.

# %%
import os, subprocess, sys
from google.colab import drive

drive.mount("/content/drive")
DRIVE_ROOT = "/content/drive/MyDrive/ad-glia-fm-prep"
os.makedirs(DRIVE_ROOT, exist_ok=True)

REPO_URL  = "https://github.com/pavlemic/ad-glia-fm-prep.git"
REPO_PATH = "/content/ad-glia-fm-prep"

if not os.path.exists(REPO_PATH):
    subprocess.run(["git", "clone", REPO_URL, REPO_PATH], check=True)
else:
    subprocess.run(["git", "-C", REPO_PATH, "pull"], check=True)

if REPO_PATH not in sys.path:
    sys.path.insert(0, REPO_PATH)

assert sys.version_info[:2] == (3, 12), f"Expected Python 3.12, got {sys.version_info[:2]}"

# Pin numpy first so pip picks numpy-1.x-compatible wheels (same rationale as colab_01-07).
# !pip install numpy==1.26.4
# !pip install -r {REPO_PATH}/requirements_integration.txt
# Leiden sub-clustering (§5) needs leidenalg + python-igraph; ensure present even if unpinned.
# !pip install leidenalg igraph
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.12/dist-packages (1.26.4)
# Requirement already satisfied: scanpy==1.10.4 in /usr/local/lib/python3.12/dist-packages (from -r /content/ad-glia-fm-prep/requirements_integration.txt (line 13)) (1.10.4)
# Requirement already satisfied: anndata==0.11.4 in /usr/local/lib/python3.12/dist-packages (from -r /content/ad-glia-fm-prep/requirements_integration.txt (line 14)) (0.11.4)
# Requirement already satisfied: leidenalg==0.10.2 in /usr/local/lib/python3.12/dist-packages (from -r /content/ad-glia-fm-prep/requirements_integration.txt (line 15)) (0.10.2)
# Requirement already satisfied: igraph==0.11.6 in /usr/local/lib/python3.12/dist-packages (from -r /content/ad-glia-fm-prep/requirements_integration.txt (line 16)) (0.11.6)
# Requirement already satisfied: umap-learn==0.5.6 in /usr/local/lib/python3.12/dist-packages (from -r /content/ad-glia-fm-prep/requirements_integration.txt (line 17)) (0.5.6)
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.12/dist-packages (from -r /content/ad-glia-fm-prep/requirements_integration.txt (line 18)) (1.26.4)
# Requirement already satisfied: pandas==2.2.3 in /usr/local/lib/python3.12/dist-packages (from -r /content/ad-glia-fm-prep/requirements_integration.txt (line 19)) (2.2.3)
# Requirement already satisfied: scipy==1.13.1 in /usr/local/lib/python3.12/dist-packages (from -r /content/ad-glia-fm-prep/requirements_integration.txt (line 20)) (1.13.1)
# Requirement already satisfied: matplotlib==3.9.2 in /usr/local/lib/python3.12/dist-packages (from -r /content/ad-glia-fm-prep/requirements_integration.txt (line 21)) (3.9.2)
# Requirement already satisfied: seaborn==0.13.2 in /usr/local/lib/python3.12/dist-packages (from -r /content/ad-glia-fm-prep/requirements_integration.txt (line 22)) (0.13.2)
# Requirement already satisfied: scikit-learn==1.5.2 in /usr/local/lib/python3.12/dist-packages (from -r /content/ad-glia-fm-prep/requirements_integration.txt (line 23)) (1.5.2)
# Requirement already satisfied: scikit-misc==0.3.1 in /usr/local/lib/python3.12/dist-packages (from -r /content/ad-glia-fm-prep/requirements_integration.txt (line 24)) (0.3.1)
# Requirement already satisfied: scrublet==0.2.3 in /usr/local/lib/python3.12/dist-packages (from -r /content/ad-glia-fm-prep/requirements_integration.txt (line 25)) (0.2.3)
# Requirement already satisfied: jupyter==1.1.1 in /usr/local/lib/python3.12/dist-packages (from -r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (1.1.1)
# Requirement already satisfied: ipykernel==6.29.5 in /usr/local/lib/python3.12/dist-packages (from -r /content/ad-glia-fm-prep/requirements_integration.txt (line 27)) (6.29.5)
# Requirement already satisfied: scvi-tools==1.4.3 in /usr/local/lib/python3.12/dist-packages (from -r /content/ad-glia-fm-prep/requirements_integration.txt (line 30)) (1.4.3)
# Requirement already satisfied: harmonypy==0.0.10 in /usr/local/lib/python3.12/dist-packages (from -r /content/ad-glia-fm-prep/requirements_integration.txt (line 31)) (0.0.10)
# Requirement already satisfied: scib-metrics==0.5.5 in /usr/local/lib/python3.12/dist-packages (from -r /content/ad-glia-fm-prep/requirements_integration.txt (line 32)) (0.5.5)
# Requirement already satisfied: h5py>=3.6 in /usr/local/lib/python3.12/dist-packages (from scanpy==1.10.4->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 13)) (3.16.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from scanpy==1.10.4->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 13)) (1.5.3)
# Requirement already satisfied: legacy-api-wrap>=1.4 in /usr/local/lib/python3.12/dist-packages (from scanpy==1.10.4->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 13)) (1.5)
# Requirement already satisfied: natsort in /usr/local/lib/python3.12/dist-packages (from scanpy==1.10.4->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 13)) (8.4.0)
# Requirement already satisfied: networkx>=2.7 in /usr/local/lib/python3.12/dist-packages (from scanpy==1.10.4->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 13)) (3.6.1)
# Requirement already satisfied: numba>=0.56 in /usr/local/lib/python3.12/dist-packages (from scanpy==1.10.4->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 13)) (0.60.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from scanpy==1.10.4->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 13)) (26.2)
# Requirement already satisfied: patsy!=1.0.0 in /usr/local/lib/python3.12/dist-packages (from scanpy==1.10.4->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 13)) (1.0.2)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.12/dist-packages (from scanpy==1.10.4->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 13)) (0.6.0)
# Requirement already satisfied: session-info in /usr/local/lib/python3.12/dist-packages (from scanpy==1.10.4->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 13)) (1.0.1)
# Requirement already satisfied: statsmodels>=0.13 in /usr/local/lib/python3.12/dist-packages (from scanpy==1.10.4->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 13)) (0.14.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from scanpy==1.10.4->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 13)) (4.67.3)
# Requirement already satisfied: array-api-compat!=1.5,>1.4 in /usr/local/lib/python3.12/dist-packages (from anndata==0.11.4->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 14)) (1.15.0)
# Requirement already satisfied: texttable>=1.6.2 in /usr/local/lib/python3.12/dist-packages (from igraph==0.11.6->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 16)) (1.7.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas==2.2.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 19)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas==2.2.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 19)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas==2.2.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 19)) (2026.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.2->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 21)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.2->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 21)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.2->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 21)) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.2->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 21)) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.2->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 21)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.2->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 21)) (3.3.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn==1.5.2->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 23)) (3.6.0)
# Requirement already satisfied: cython in /usr/local/lib/python3.12/dist-packages (from scrublet==0.2.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 25)) (3.0.12)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from scrublet==0.2.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 25)) (0.25.2)
# Requirement already satisfied: annoy in /usr/local/lib/python3.12/dist-packages (from scrublet==0.2.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 25)) (1.17.3)
# Requirement already satisfied: notebook in /usr/local/lib/python3.12/dist-packages (from jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (6.5.7)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.12/dist-packages (from jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (6.6.3)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.12/dist-packages (from jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (7.17.1)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.12/dist-packages (from jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (7.7.1)
# Requirement already satisfied: jupyterlab in /usr/local/lib/python3.12/dist-packages (from jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (4.6.1)
# Requirement already satisfied: comm>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.29.5->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 27)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.29.5->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 27)) (1.8.15)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.29.5->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 27)) (7.34.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.29.5->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 27)) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.29.5->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 27)) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.29.5->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 27)) (0.2.2)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.29.5->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 27)) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.29.5->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 27)) (5.9.5)
# Requirement already satisfied: pyzmq>=24 in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.29.5->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 27)) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.29.5->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 27)) (6.5.7)
# Requirement already satisfied: traitlets>=5.4.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.29.5->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 27)) (5.7.1)
# Requirement already satisfied: docrep>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from scvi-tools==1.4.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 30)) (0.3.2)
# Requirement already satisfied: lightning>=2.0 in /usr/local/lib/python3.12/dist-packages (from scvi-tools==1.4.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 30)) (2.6.5)
# Requirement already satisfied: ml-collections in /usr/local/lib/python3.12/dist-packages (from scvi-tools==1.4.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 30)) (1.1.0)
# Requirement already satisfied: mudata in /usr/local/lib/python3.12/dist-packages (from scvi-tools==1.4.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 30)) (0.3.9)
# Requirement already satisfied: pyro-ppl in /usr/local/lib/python3.12/dist-packages (from scvi-tools==1.4.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 30)) (1.9.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from scvi-tools==1.4.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 30)) (13.9.4)
# Requirement already satisfied: sparse>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from scvi-tools==1.4.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 30)) (0.19.0)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.12/dist-packages (from scvi-tools==1.4.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 30)) (2.20.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from scvi-tools==1.4.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 30)) (2.11.0+cpu)
# Requirement already satisfied: torchmetrics in /usr/local/lib/python3.12/dist-packages (from scvi-tools==1.4.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 30)) (1.9.0)
# Requirement already satisfied: xarray in /usr/local/lib/python3.12/dist-packages (from scvi-tools==1.4.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 30)) (2025.12.0)
# Requirement already satisfied: chex in /usr/local/lib/python3.12/dist-packages (from scib-metrics==0.5.5->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 32)) (0.1.92)
# Requirement already satisfied: jax in /usr/local/lib/python3.12/dist-packages (from scib-metrics==0.5.5->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 32)) (0.7.1)
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.12/dist-packages (from scib-metrics==0.5.5->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 32)) (0.7.1)
# Requirement already satisfied: plottable in /usr/local/lib/python3.12/dist-packages (from scib-metrics==0.5.5->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 32)) (0.1.5)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from docrep>=0.3.2->scvi-tools==1.4.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 30)) (1.17.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel==6.29.5->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 27)) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel==6.29.5->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 27)) (0.20.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel==6.29.5->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 27)) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel==6.29.5->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 27)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel==6.29.5->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 27)) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel==6.29.5->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 27)) (2.20.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel==6.29.5->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 27)) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel==6.29.5->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 27)) (4.9.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel==6.29.5->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 27)) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel==6.29.5->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 27)) (4.10.0)
# Requirement already satisfied: PyYAML<8.0,>5.4 in /usr/local/lib/python3.12/dist-packages (from lightning>=2.0->scvi-tools==1.4.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 30)) (6.0.3)
# Requirement already satisfied: fsspec<2028.0,>=2022.5.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0->scvi-tools==1.4.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 30)) (2025.3.0)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from lightning>=2.0->scvi-tools==1.4.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 30)) (0.15.3)
# Requirement already satisfied: typing-extensions<6.0,>4.5.0 in /usr/local/lib/python3.12/dist-packages (from lightning>=2.0->scvi-tools==1.4.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 30)) (4.15.0)
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.12/dist-packages (from lightning>=2.0->scvi-tools==1.4.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 30)) (2.6.5)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.56->scanpy==1.10.4->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 13)) (0.43.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools==1.4.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 30)) (3.29.4)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools==1.4.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 30)) (1.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools==1.4.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 30)) (3.1.6)
# Requirement already satisfied: absl-py>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from chex->scib-metrics==0.5.5->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 32)) (2.4.0)
# Requirement already satisfied: toolz>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from chex->scib-metrics==0.5.5->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 32)) (1.1.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from jax->scib-metrics==0.5.5->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 32)) (0.5.4)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.12/dist-packages (from jax->scib-metrics==0.5.5->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 32)) (3.4.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (3.0.16)
# Requirement already satisfied: async-lru>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (2.3.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (0.28.1)
# Requirement already satisfied: jupyter-builder>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (1.0.2)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (2.3.1)
# Requirement already satisfied: jupyter-server<3,>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (2.20.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (0.2.4)
# Requirement already satisfied: scverse-misc<=0.1.1,>=0.0.3 in /usr/local/lib/python3.12/dist-packages (from mudata->scvi-tools==1.4.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 30)) (0.1.1)
# Requirement already satisfied: session-info2 in /usr/local/lib/python3.12/dist-packages (from mudata->scvi-tools==1.4.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 30)) (0.4.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (6.4.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (3.0.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (3.3.2)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (0.10.4)
# Requirement already satisfied: nbformat>=5.7 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (1.5.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (25.1.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (0.25.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (1.3.3)
# Requirement already satisfied: pyro-api>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from pyro-ppl->scvi-tools==1.4.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 30)) (0.1.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->scvi-tools==1.4.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 30)) (4.2.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->scrublet==0.2.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 25)) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->scrublet==0.2.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 25)) (2026.3.3)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->scrublet==0.2.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 25)) (0.5)
# Requirement already satisfied: stdlib_list in /usr/local/lib/python3.12/dist-packages (from session-info->scanpy==1.10.4->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 13)) (0.12.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard->scvi-tools==1.4.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 30)) (1.81.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard->scvi-tools==1.4.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 30)) (3.10.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.12/dist-packages (from tensorboard->scvi-tools==1.4.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 30)) (5.29.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard->scvi-tools==1.4.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 30)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard->scvi-tools==1.4.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 30)) (3.1.8)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (0.5.1)
# Requirement already satisfied: tinycss2>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (1.5.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0->scvi-tools==1.4.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 30)) (3.14.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (4.14.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (0.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel==6.29.5->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 27)) (0.8.7)
# Requirement already satisfied: jupyter-events>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (0.5.4)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (1.9.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi->notebook->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (25.1.0)
# Requirement already satisfied: babel>=2.10 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (0.15.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (4.26.0)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (2.32.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->scvi-tools==1.4.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 30)) (0.1.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat>=5.7->nbconvert->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (2.21.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel==6.29.5->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 27)) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel==6.29.5->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 27)) (0.8.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->scvi-tools==1.4.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 30)) (1.3.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (2.8.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0->scvi-tools==1.4.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 30)) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0->scvi-tools==1.4.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 30)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0->scvi-tools==1.4.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 30)) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0->scvi-tools==1.4.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 30)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0->scvi-tools==1.4.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 30)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0->scvi-tools==1.4.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 30)) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0->scvi-tools==1.4.3->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 30)) (1.24.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (2026.5.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (4.1.0)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (0.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (2.5.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (3.0)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (25.10.0)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter==1.1.1->-r /content/ad-glia-fm-prep/requirements_integration.txt (line 26)) (1.4.0)
# Requirement already satisfied: leidenalg in /usr/local/lib/python3.12/dist-packages (0.10.2)
# Requirement already satisfied: igraph in /usr/local/lib/python3.12/dist-packages (0.11.6)
# Requirement already satisfied: texttable>=1.6.2 in /usr/local/lib/python3.12/dist-packages (from igraph) (1.7.0)

# %% [markdown]
# > **Interpretation — setup (1a).**
# >
# > Integration env resolves cleanly — scanpy 1.10.4, anndata 0.11.4, leidenalg 0.10.2, igraph 0.11.6 all report *already satisfied* (same runtime as the earlier colab_04–07 notebooks), Drive is already mounted, and the repo is pulled. Environment only, no findings.

# %% [markdown]
# ## 2 — Environment capture

# %% [markdown]
# ### 2a — pip freeze + env JSON
#
# Identical reproducibility snapshot to the earlier notebooks: full `pip freeze` plus a structured JSON of Python / OS / library versions and the repo commit, written under `outputs/software_versions/`. Methods sections need the exact versions present at run time, not the pin file.

# %%
import json, platform, subprocess, sys
from datetime import date

NOTEBOOK_ID = "colab_08"
TODAY = date.today().isoformat()
VERSIONS_DIR = os.path.join(REPO_PATH, "outputs", "software_versions")
os.makedirs(VERSIONS_DIR, exist_ok=True)

FREEZE_PATH = os.path.join(VERSIONS_DIR, f"{NOTEBOOK_ID}_{TODAY}_pip_freeze.txt")
# !pip freeze > {FREEZE_PATH}

def _run(cmd):
    try:
        return subprocess.run(cmd, capture_output=True, text=True, check=True).stdout.strip()
    except (FileNotFoundError, subprocess.CalledProcessError):
        return None

def _ver(mod):
    try:
        return __import__(mod).__version__
    except Exception:
        return None

env_snapshot = {
    "notebook_id":   NOTEBOOK_ID,
    "date":          TODAY,
    "python_version": sys.version,
    "platform":      platform.platform(),
    "os_release":    platform.release(),
    "gpu":           _run(["nvidia-smi", "-L"]),
    "git_commit":    _run(["git", "-C", REPO_PATH, "rev-parse", "HEAD"]),
    "scanpy_version":   _ver("scanpy"),
    "anndata_version":  _ver("anndata"),
    "leidenalg_version":_ver("leidenalg"),
}
ENV_JSON_PATH = os.path.join(VERSIONS_DIR, f"{NOTEBOOK_ID}_{TODAY}_env.json")
with open(ENV_JSON_PATH, "w") as f:
    json.dump(env_snapshot, f, indent=2)
print(json.dumps(env_snapshot, indent=2))
# Out:
# {
#   "notebook_id": "colab_08",
#   "date": "2026-07-02",
#   "python_version": "3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]",
#   "platform": "Linux-6.6.122+-x86_64-with-glibc2.35",
#   "os_release": "6.6.122+",
#   "gpu": null,
#   "git_commit": "7bbfd1450765e43d21fe4374724b0345864a28b6",
#   "scanpy_version": "1.10.4",
#   "anndata_version": "0.11.4",
#   "leidenalg_version": null
# }

# %% [markdown]
# > **Interpretation — environment capture (2a).**
# >
# > Pinned for the Methods record: Python 3.12.13, scanpy 1.10.4, anndata 0.11.4, git commit `7bbfd145...` (the colab_08 Phase-2 fix commit). `gpu: null` is expected — this notebook is CPU-only (subclustering, scoring, DE); no GPU is needed until the FM notebooks. `leidenalg_version: null` is the same version-probe quirk colab_07 hit — leidenalg 0.10.2 is installed per §1a and is the Leiden backend actually used in §5a, it just doesn't expose `__version__` the way the probe checks for it.

# %% [markdown]
# ## 3 — Load the glia subset + carve out astrocytes

# %% [markdown]
# ### 3a — Load `glia_subset_full.h5ad`, subset astrocytes, sanity-check latent + raw counts
#
# Load the colab_05 glia hand-off object (astrocytes + microglia, 149,375 cells; carries raw counts in `.X`, the scVI latent `X_scVI`, the original `leiden_scvi` clusters, and `cell_type`). Fail loud unless those are present and `.X` is integer counts. Then carve out the astrocytes (`cell_type == "astrocyte"`, ca. 94,271 cells) — colab_05 promoted cl32 to astrocyte and split perivascular macrophages (old cl0) into their own `cell_type`, so both are already handled by the `cell_type` field. The colab_05-flagged astrocyte clusters (**22 / 33 / 42 / 45**) are still present in this subset and are adjudicated in §4a before sub-clustering. Print the astrocyte cluster × study table, donor count, and APOE breakdown so the working set is characterized before anything is done to it.

# %%
import gc
import numpy as np
import pandas as pd
import anndata as ad
import scanpy as sc
import scipy.sparse as sp
import matplotlib.pyplot as plt

try:
    import psutil
    def _ram(tag):
        m = psutil.virtual_memory()
        print(f"[RAM] {tag:24s}: {m.used/1e9:5.1f} / {m.total/1e9:.1f} GB ({m.percent:.0f}%)")
except ImportError:
    def _ram(tag): pass

sc.settings.verbosity = 1
FIG_DIR = os.path.join(REPO_PATH, "figures", "colab_08")
os.makedirs(FIG_DIR, exist_ok=True)

GLIA_PATH = os.path.join(DRIVE_ROOT, "glia_subset", "glia_subset_full.h5ad")
if not os.path.exists(GLIA_PATH):
    raise FileNotFoundError(f"missing colab_05 glia subset {GLIA_PATH}")
glia = sc.read_h5ad(GLIA_PATH)
print("loaded glia subset:", glia.shape)

assert "X_scVI" in glia.obsm, "X_scVI missing — colab_05 glia subset expected"
assert "leiden_scvi" in glia.obs.columns, "leiden_scvi missing — needed for cluster verdicts"
assert "cell_type" in glia.obs.columns, "cell_type missing — needed to carve astrocytes"

# raw-counts guard (sorted deposits hide non-integer tails in a head slice -> random sample)
_idx = np.random.default_rng(0).choice(glia.n_obs, size=min(2000, glia.n_obs), replace=False)
Xs = glia.X[_idx]
data = Xs.data if sp.issparse(Xs) else np.asarray(Xs).ravel()
frac_int = float(np.mean(np.mod(data, 1) == 0)) if data.size else 1.0
assert frac_int >= 0.99, f".X is not raw counts (int frac {frac_int:.3f})"

# carve out astrocytes (cl0 = perivascular_mac split off in colab_05; cl32 promoted TO astrocyte)
astro = glia[glia.obs["cell_type"] == "astrocyte"].copy()
astro.obs["leiden_scvi"] = astro.obs["leiden_scvi"].astype(str)
del glia; gc.collect()
print("astrocyte subset:", astro.shape)
print("\nastrocyte leiden_scvi x study (counts):")
print(pd.crosstab(astro.obs["leiden_scvi"], astro.obs["study_id"]))
print("\ndonors:", astro.obs["donor_id"].nunique(),
      "| apoe_carrier:", astro.obs["apoe_carrier"].value_counts(dropna=False).to_dict())
_ram("astrocyte subset")
# Out:
# loaded glia subset: (149375, 26514)
# astrocyte subset: (94271, 26514)
#
# astrocyte leiden_scvi x study (counts):
# study_id     Li2025  SEA-AD  Haney2024
# leiden_scvi
# 22             3397      72         57
# 28             7244   15312       1969
# 30             1969    1746       2625
# 31             2406    9046       2089
# 32            15092   20873       6307
# 33                1    1095          9
# 42               12    1979          5
# 45                0     961          5
#
# donors: 145 | apoe_carrier: {'noncarrier': 47018, 'carrier': 32407, 'e2': 14846}
# [RAM] astrocyte subset        :   6.6 / 54.8 GB (13%)

# %% [markdown]
# > **Interpretation — load + astrocyte carve-out (3a).**
# >
# > The colab_05 glia hand-off reloads exactly as saved — **149,375 × 26,514** — and subsetting to `cell_type == "astrocyte"` gives **94,271 cells**, matching the colab_05 handoff number exactly. The `leiden_scvi × study` crosstab carries all eight astrocyte clusters from colab_05 ({22,28,30,31,32,33,42,45}), and the counts sum to 94,271 with no cells silently dropped in the carve. The four colab_05-flagged clusters are already visible here in raw form — cl22 (3,526 cells, 96.3% Li), cl42 (1,996, 99.1% SEA-AD), cl45 (966, 99.5% SEA-AD), cl33 (1,105, 99.1% SEA-AD) — adjudicated properly in §4a.
# >
# > **145 donors** carried, matching the post-colab_04 cohort exactly. APOE breakdown **noncarrier 47,018 / carrier 32,407 / e2 14,846** also sums to 94,271 — no NaNs introduced. RAM 13% — comfortable headroom for the sub-clustering ahead.

# %% [markdown]
# ## 4 — Apply colab_05 astrocyte cluster verdicts

# %% [markdown]
# ### 4a — Confirm the colab_05 per-cluster verdicts on this subset (composition, ambient, DE)
#
# colab_05's astrocyte adjudication already ran the heavy six-lever residual-batch battery and issued per-cluster verdicts. This cell does **not** re-adjudicate — it **re-confirms** that those verdicts still describe the clusters as they sit in this subset, then records the disposition that §5a will apply. For each colab_05-flagged cluster it reports:
#
# - **cl22 = `ambient` → drop.** colab_05 found it Li-pure (0.963) with oligodendrocyte/myelin contamination — an ambient-RNA pocket, not an astrocyte substate. Dropped so it cannot seed a spurious "ambient" subcluster or leak into the reactive axis.
# - **cl42 / cl45 = `donor_effect` → drop (provisional).** Each is ca. 98% a single donor with a technical signature (heat-shock / high-depth). By the cl44 precedent (colab_07 §5a) a donor-pure technical pocket is dropped *before* sub-clustering so it cannot mint its own substate. The trade-off: these are genuine astrocytes leaving the CPT substrate — flip their entry in `ASTRO_CLUSTER_VERDICTS` to `keep` to retain-and-flag instead.
# - **cl33 = `real_confounded` → keep (flagged).** Single-donor but the only metabolic program that replicated cross-study in colab_05 — real biology. Kept, but it stays donor-confounded, so §6b re-flags it and eval #1/#2 must treat any cl33-driven signal as single-donor (unevaluable as a generalizable win).
#
# Evidence assembled: per-cluster composition (dominant donor / study fraction, median counts, ambient proxy) for **all** astrocyte clusters with the flagged four highlighted; a lineage-marker dotplot (astro vs oligo / microglia / neuron) so cl22's off-lineage ambient band is visible; and Wilcoxon DE of each flagged cluster vs the rest (astro-subset only — within the project's compute budget, never on the full object). The dispositions are set in `ASTRO_CLUSTER_VERDICTS`; §5a applies the drops.

# %%
# log-normalized layer for scoring/DE (.X stays raw counts) — rebuilt on the astro subset
astro.layers["lognorm"] = astro.X.copy()
sc.pp.normalize_total(astro, target_sum=1e4, layer="lognorm")
astro.uns.pop("log1p", None)
sc.pp.log1p(astro, layer="lognorm")
astro.uns.pop("log1p", None)

# colab_05 per-cluster verdicts (this cell re-CONFIRMS them, it does not re-adjudicate).
# default disposition applied in §5a: drop = removed before sub-clustering; keep = retained.
COLAB05_FLAGGED = {
    "22": {"colab05_verdict": "ambient",         "disposition": "drop",
           "why": "Li-pure (0.963) oligo/myelin ambient contamination, not an astro substate"},
    "42": {"colab05_verdict": "donor_effect",    "disposition": "drop",
           "why": "~98% single donor, heat-shock technical signature (cl44 precedent: drop before subclustering)"},
    "45": {"colab05_verdict": "donor_effect",    "disposition": "drop",
           "why": "~98% single donor, high-depth technical signature (cl44 precedent: drop before subclustering)"},
    "33": {"colab05_verdict": "real_confounded", "disposition": "keep",
           "why": "single-donor but only metabolic program replicating cross-study — real biology; kept + flagged"},
}
present_flagged = [cl for cl in COLAB05_FLAGGED if cl in set(astro.obs["leiden_scvi"])]
missing_flagged = [cl for cl in COLAB05_FLAGGED if cl not in present_flagged]
if missing_flagged:
    print(f"[verdicts] colab_05-flagged clusters absent from this subset (already handled upstream?): {missing_flagged}")

# ambient / off-lineage proxy: oligo + microglia + neuron markers (astro should be low on all three)
AMBIENT = [g for g in ["MBP","PLP1","MOBP","CSF1R","P2RY12","AIF1","SNAP25","RBFOX3"]
           if g in astro.var_names]
X_raw = astro.X
astro.X = astro.layers["lognorm"]
try:
    sc.tl.score_genes(astro, gene_list=AMBIENT, score_name="score_ambient", use_raw=False)
finally:
    astro.X = X_raw

# per-cluster composition for ALL astro clusters (flagged four highlighted below)
rows = []
for cl, idx in astro.obs.groupby("leiden_scvi", observed=True).groups.items():
    o = astro.obs.loc[idx]
    rows.append({
        "cluster": str(cl), "n": len(o),
        "top_donor_frac": round(float(o["donor_id"].value_counts(normalize=True).iloc[0]), 3),
        "top_study_frac": round(float(o["study_id"].value_counts(normalize=True).iloc[0]), 3),
        "median_counts": int(o["total_counts"].median()) if "total_counts" in o.columns else -1,
        "mean_ambient": round(float(o["score_ambient"].mean()), 3),
    })
comp = pd.DataFrame(rows).set_index("cluster")
print("per-astro-cluster composition (all clusters):")
with pd.option_context("display.width", 160):
    print(comp.sort_index(key=lambda s: s.astype(int)))
print("\ncolab_05-flagged clusters (verdict re-confirmation):")
print(comp.loc[present_flagged])
for cl in present_flagged:
    print(f"  cl{cl}: colab_05={COLAB05_FLAGGED[cl]['colab05_verdict']:15s} -> {COLAB05_FLAGGED[cl]['disposition']:4s} | {COLAB05_FLAGGED[cl]['why']}")

# lineage-marker dotplot: astro vs oligo/micro/neuron across all astro clusters
# (cl22 ambient should show an off-lineage oligo/myelin band)
DOT_GENES = ["AQP4","SLC1A2","GJA1","SLC1A3","GFAP",
             "MBP","PLP1","MOBP","CSF1R","P2RY12","AIF1","SNAP25","RBFOX3"]
dot_present = [g for g in DOT_GENES if g in astro.var_names]
X_raw = astro.X
astro.X = astro.layers["lognorm"]
try:
    sc.pl.dotplot(astro, dot_present, groupby="leiden_scvi", standard_scale="var", show=False)
    plt.savefig(os.path.join(FIG_DIR, "4a_astrocyte_cluster_marker_dotplot.png"),
                dpi=150, bbox_inches="tight")
    plt.show()  # render inline AND keep the saved PNG
finally:
    astro.X = X_raw

# DE of each flagged cluster vs a MIXED-REFERENCE backbone (astro-subset Wilcoxon — within budget).
# reference="rest" would fold the OTHER flagged clusters into the reference, so a program shared
# between flagged clusters (e.g. cl42/cl45's shared heat-shock/high-depth signature) partially
# cancels out of both sides -- the same sibling-cancellation issue colab_05 §6a/§6e fixed with a
# mixed-reference backbone. Reuse that pattern: astro clusters NOT in present_flagged are the
# mixed reference group.
astro.obs["batch_grp"] = np.where(astro.obs["leiden_scvi"].isin(present_flagged),
                                  astro.obs["leiden_scvi"].astype(str), "mixed_ref")
X_raw = astro.X
astro.X = astro.layers["lognorm"]
try:
    sc.tl.rank_genes_groups(astro, groupby="batch_grp", groups=present_flagged, reference="mixed_ref",
                            method="wilcoxon", key_added="flagged_vs_rest")
finally:
    astro.X = X_raw
print("\ntop-12 up genes per flagged cluster (vs mixed-reference astrocytes):")
for cl in present_flagged:
    print(f"  cl{cl}:", pd.DataFrame(astro.uns["flagged_vs_rest"]["names"])[cl].head(12).tolist())

# DISPOSITION applied in §5a. Drop clusters cannot seed a spurious substate subcluster (cl44 lesson).
# Flip any entry to "keep" here to retain the cl42/cl45 donor-effect clusters instead of dropping them.
ASTRO_CLUSTER_VERDICTS = {cl: COLAB05_FLAGGED[cl]["disposition"] for cl in present_flagged}
print("\n[verdicts] disposition applied in §5a:", ASTRO_CLUSTER_VERDICTS)
# Out:
# per-astro-cluster composition (all clusters):
#              n  top_donor_frac  top_study_frac  median_counts  mean_ambient
# cluster
# 22        3526           0.086           0.963           7542         0.743
# 28       24525           0.074           0.624           7956        -0.069
# 30        6340           0.213           0.414           5652        -0.056
# 31       13541           0.040           0.668           6063        -0.038
# 32       42272           0.042           0.494           7327        -0.025
# 33        1105           0.978           0.991           6007         0.011
# 42        1996           0.988           0.991           8908        -0.069
# 45         966           0.987           0.995          21126        -0.118
#
# colab_05-flagged clusters (verdict re-confirmation):
#             n  top_donor_frac  top_study_frac  median_counts  mean_ambient
# cluster
# 22       3526           0.086           0.963           7542         0.743
# 42       1996           0.988           0.991           8908        -0.069
# 45        966           0.987           0.995          21126        -0.118
# 33       1105           0.978           0.991           6007         0.011
#   cl22: colab_05=ambient         -> drop | Li-pure (0.963) oligo/myelin ambient contamination, not an astro substate
#   cl42: colab_05=donor_effect    -> drop | ~98% single donor, heat-shock technical signature (cl44 precedent: drop before subclustering)
#   cl45: colab_05=donor_effect    -> drop | ~98% single donor, high-depth technical signature (cl44 precedent: drop before subclustering)
#   cl33: colab_05=real_confounded -> keep | single-donor but only metabolic program replicating cross-study — real biology; kept + flagged
# top-12 up genes per flagged cluster (vs mixed-reference astrocytes):
#   cl22: ['ELMO1', 'DOCK10', 'PLXDC2', 'FRMD4B', 'MBP', 'SHTN1', 'MARCH1', 'ZEB2', 'PLP1', 'PIP4K2A', 'DPYD', 'PICALM']
#   cl42: ['HSPB1', 'HSP90AA1', 'PLCG2', 'LINC00299', 'HSPH1', 'HMGB1', 'DNAJB1', 'LINC00472', 'NEAT1', 'AC119674.1', 'PTGES3', 'MIB1']
#   cl45: ['PLCG2', 'MTRNR2L12', 'KCNMB2-AS1', 'LINC00472', 'MT-ATP8', 'ASB3', 'PCDH9', 'MEF2C-AS1', 'MAPK10', 'MEIKIN', 'SYNE1', 'LINC00499']
#   cl33: ['SASH1', 'RASSF8', 'NEAT1', 'LINC00472', 'NPAS2', 'SOX5', 'MRPS6', 'SSBP2', 'FNDC3B', 'PLPP1', 'CLIP2', 'CACNB2']
#
# [verdicts] disposition applied in §5a: {'22': 'drop', '42': 'drop', '45': 'drop', '33': 'keep'}

# %% [markdown]
# > **Interpretation — colab_05 verdict re-confirmation (4a).**
# >
# > The per-cluster composition table sums exactly to 94,271, and the four colab_05-flagged clusters reproduce their original fractions precisely: **cl22 = 96.3% Li** (0.963), **cl33 = 97.8% one donor** (0.978), **cl42 = 98.8% one donor**, **cl45 = 98.7% one donor** with median depth **21,126 counts** — an exact match to colab_05's own number for the same cluster. The DE gene lists independently reproduce colab_05's mechanism calls on a fresh mixed-ref comparison run on this subset alone: **cl22 → MBP, PLP1** (myelin) confirms ambient oligo contamination; **cl42 → HSPB1, HSP90AA1, HSPH1, DNAJB1** (heat-shock genes) confirms donor stress; **cl45 →** mitochondrial-associated genes (MT-ATP8, MTRNR2L12) consistent with the high-depth technical call; **cl33 → NPAS2 recurs**, the same circadian/metabolic transcription factor colab_05's §6e/§6f used to call it a real, cross-study-replicating astrocyte program — good cross-notebook reproducibility, and confirmation the Phase-2 `mixed_ref` DE fix (vs. the sibling-cancelling `rest` reference) behaves correctly.
# >
# > The dotplot adds two things the tables don't show. First, **cl22's contamination is broader than "oligo/myelin" alone** — CSF1R and P2RY12 (microglial markers) are also visibly elevated, not just MBP/PLP1/MOBP, so the ambient signal is multi-lineage, not oligo-specific; this doesn't change the drop decision. Second, **cl33 shows a prominent SNAP25 dot** (a neuronal synaptic marker) that was not part of colab_05's automated nuisance panel (which checked ribo/mito/sex/ambient, not neuronal contamination specifically) — raised as an open question during review but **not resolved this session**; it doesn't block the keep-and-flag verdict (cl33 already carries a donor/study confound caveat into eval#2 regardless) but is carried forward as an unresolved watch item, not a settled finding.
# >
# > **Verdicts applied:** cl22 (ambient) + cl42/cl45 (donor_effect) → drop; cl33 (real_confounded) → keep + flag. Disposition dict: `{'22': 'drop', '42': 'drop', '45': 'drop', '33': 'keep'}`.

# %% [markdown]
# ## 5 — Astrocyte sub-clustering

# %% [markdown]
# ### 5a — Apply the verdict drops, then Neighbors + Leiden on `X_scVI` within astrocytes + UMAP + per-subcluster DE
#
# The global 46-cluster solution split the astrocytes only coarsely (into the {22,28,30,31,32,33,42,45} block), so within-astrocyte substate structure is not resolved at that resolution. Re-running the neighbor graph and Leiden **on the astrocytes only** — on the same scVI latent used throughout (consistent with how colab_05/07 worked each lineage) — lets finer substates separate. A within-astrocyte re-embedding (fresh HVGs / PCA) is the fallback if substates do not resolve on the integration latent.
#
# **Verdicts applied first.** The §4a dispositions (drop cl22 ambient + cl42/cl45 donor-effect; keep cl33 flagged) are applied at the top of this cell, *before* sub-clustering, so a technical / ambient pocket cannot seed its own substate subcluster — the same cl44 precedent from colab_07 §5a. Flip an entry in `ASTRO_CLUSTER_VERDICTS` to `keep` to retain it.
#
# **Why the resolution matters here:** §6a assigns one substate label *per subcluster* (the mean reactive/resting z-score axis over each Leiden group), so the partition is load-bearing — too coarse dilutes a real reactive pocket into "intermediate" by averaging it with resting neighbours; too fine fragments one substate into noisy groups with unstable means. We keep cluster-level assignment (for its denoising) at a primary `resolution=1.0`, and report an ARI-stability check at res 0.5 / 1.5 so the post-run interp can judge how sensitive the partition is. The resolution-independent alternative — thresholding each cell's continuous score directly — was declined here (same as colab_07) because it forfeits that denoising and is noisier at single-cell level.
#
# The UMAPs are coloured by subcluster, study (to spot any subcluster that is one study only), and APOE. Per-subcluster Wilcoxon DE gives each subcluster its top markers for the substate read in §6.

# %%
# apply the §4a verdicts BEFORE sub-clustering, so an ambient/technical pocket cannot seed its own
# substate subcluster (cl44 precedent, colab_07 §5a)
drop_clusters = [cl for cl, v in ASTRO_CLUSTER_VERDICTS.items() if v == "drop"]
if drop_clusters:
    _before = astro.n_obs
    astro = astro[~astro.obs["leiden_scvi"].isin(drop_clusters)].copy()
    print(f"[verdicts] dropped clusters {drop_clusters}: {_before - astro.n_obs} cells; astrocytes now {astro.n_obs}")
else:
    print("[verdicts] no clusters marked drop — full astrocyte set retained")
kept_flagged = [cl for cl, v in ASTRO_CLUSTER_VERDICTS.items() if v == "keep"]
if kept_flagged:
    print(f"[verdicts] kept + flagged (still confounded, re-flagged in §6b): {kept_flagged}")

# sub-cluster astrocytes on the scVI latent (consistent with colab_05/07 use of X_scVI)
sc.pp.neighbors(astro, use_rep="X_scVI", n_neighbors=15, random_state=0)
sc.tl.leiden(astro, resolution=1.0, key_added="leiden_astro", random_state=0)
sc.tl.umap(astro, random_state=0)
print("astro subclusters:", astro.obs["leiden_astro"].nunique())
print(astro.obs["leiden_astro"].value_counts().sort_index())

# resolution-stability sanity-check: §6a assigns ONE substate label per subcluster (mean score),
# so the Leiden resolution is load-bearing. Report subcluster counts + ARI vs the primary res=1.0
# at neighbouring resolutions so the _OUTPUT interp can judge how stable the partition is.
from sklearn.metrics import adjusted_rand_score
print("\nresolution stability (vs res=1.0):")
for r in (0.5, 1.5):
    sc.tl.leiden(astro, resolution=r, key_added=f"_leiden_r{r}", random_state=0)
    ari = adjusted_rand_score(astro.obs["leiden_astro"], astro.obs[f"_leiden_r{r}"])
    print(f"  res={r}: {astro.obs[f'_leiden_r{r}'].nunique()} subclusters, ARI vs res=1.0 = {ari:.3f}")
    del astro.obs[f"_leiden_r{r}"]
    astro.uns.pop(f"_leiden_r{r}", None)  # sc.tl.leiden also writes a params dict here; drop the leftover

print("\nleiden_astro x study (row-normalized):")
print(pd.crosstab(astro.obs["leiden_astro"], astro.obs["study_id"], normalize="index").round(3))

# per-subcluster marker DE (astro-subset Wilcoxon — within budget per the project rule)
X_raw = astro.X
astro.X = astro.layers["lognorm"]
try:
    sc.tl.rank_genes_groups(astro, "leiden_astro", method="wilcoxon", key_added="astro_de")
finally:
    astro.X = X_raw
print("\ntop-8 markers per astro subcluster:")
print(pd.DataFrame(astro.uns["astro_de"]["names"]).head(8))

# UMAPs
for color in ["leiden_astro", "study_id", "apoe_carrier"]:
    loc = "on data" if color == "leiden_astro" else "right margin"
    sc.pl.umap(astro, color=color, show=False, legend_loc=loc)
    plt.savefig(os.path.join(FIG_DIR, f"5a_umap_{color}.png"), dpi=150, bbox_inches="tight")
    plt.show()  # render inline AND keep the saved PNG
_ram("after subclustering")
# Out:
# [verdicts] dropped clusters ['22', '42', '45']: 6488 cells; astrocytes now 87783
# [verdicts] kept + flagged (still confounded, re-flagged in §6b): ['33']
# /tmp/ipykernel_21934/4045765268.py:16: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(astro, resolution=1.0, key_added="leiden_astro", random_state=0)
# astro subclusters: 28
# leiden_astro
# 0     10197
# 1      7144
# 2      7026
# 3      6886
# 4      6242
# 5      5773
# 6      4041
# 7      3830
# 8      3494
# 9      3355
# 10     3334
# 11     3285
# 12     3255
# 13     2655
# 14     2329
# 15     2271
# 16     2265
# 17     2244
# 18     1557
# 19     1136
# 20     1091
# 21      922
# 22      700
# 23      653
# 24      619
# 25      543
# 26      481
# 27      455
# Name: count, dtype: int64
#
# resolution stability (vs res=1.0):
#   res=0.5: 17 subclusters, ARI vs res=1.0 = 0.630
#   res=1.5: 41 subclusters, ARI vs res=1.0 = 0.643
#
# leiden_astro x study (row-normalized):
# study_id      Li2025  SEA-AD  Haney2024
# leiden_astro
# 0              0.365   0.490      0.145
# 1              0.500   0.440      0.060
# 2              0.069   0.761      0.170
# 3              0.362   0.494      0.144
# 4              0.217   0.599      0.184
# 5              0.825   0.100      0.074
# 6              0.187   0.807      0.006
# 7              0.131   0.713      0.156
# 8              0.946   0.041      0.013
# 9              0.032   0.758      0.210
# 10             0.056   0.765      0.179
# 11             0.435   0.126      0.439
# 12             0.151   0.747      0.101
# 13             0.011   0.518      0.472
# 14             0.113   0.879      0.007
# 15             0.056   0.880      0.064
# 16             0.367   0.173      0.460
# 17             0.005   0.838      0.157
# 18             0.005   0.761      0.234
# 19             0.002   0.996      0.002
# 20             0.027   0.966      0.007
# 21             0.965   0.026      0.009
# 22             0.154   0.803      0.043
# 23             0.963   0.025      0.012
# 24             0.966   0.018      0.016
# 25             0.020   0.346      0.634
# 26             0.008   0.992      0.000
# 27             0.007   0.989      0.004
# /usr/local/lib/python3.12/dist-packages/scanpy/tools/_rank_genes_groups.py:429: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "names"] = self.var_names[global_indices]
# /usr/local/lib/python3.12/dist-packages/scanpy/tools/_rank_genes_groups.py:431: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "scores"] = scores[global_indices]
# /usr/local/lib/python3.12/dist-packages/scanpy/tools/_rank_genes_groups.py:434: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals"] = pvals[global_indices]
# /usr/local/lib/python3.12/dist-packages/scanpy/tools/_rank_genes_groups.py:444: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals_adj"] = pvals_adj[global_indices]
# /usr/local/lib/python3.12/dist-packages/scanpy/tools/_rank_genes_groups.py:455: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# /usr/local/lib/python3.12/dist-packages/scanpy/tools/_rank_genes_groups.py:429: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "names"] = self.var_names[global_indices]
# /usr/local/lib/python3.12/dist-packages/scanpy/tools/_rank_genes_groups.py:431: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "scores"] = scores[global_indices]
# /usr/local/lib/python3.12/dist-packages/scanpy/tools/_rank_genes_groups.py:434: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals"] = pvals[global_indices]
# /usr/local/lib/python3.12/dist-packages/scanpy/tools/_rank_genes_groups.py:444: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals_adj"] = pvals_adj[global_indices]
# /usr/local/lib/python3.12/dist-packages/scanpy/tools/_rank_genes_groups.py:455: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# /usr/local/lib/python3.12/dist-packages/scanpy/tools/_rank_genes_groups.py:429: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "names"] = self.var_names[global_indices]
# /usr/local/lib/python3.12/dist-packages/scanpy/tools/_rank_genes_groups.py:431: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "scores"] = scores[global_indices]
# /usr/local/lib/python3.12/dist-packages/scanpy/tools/_rank_genes_groups.py:434: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals"] = pvals[global_indices]
# /usr/local/lib/python3.12/dist-packages/scanpy/tools/_rank_genes_groups.py:444: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals_adj"] = pvals_adj[global_indices]
# /usr/local/lib/python3.12/dist-packages/scanpy/tools/_rank_genes_groups.py:455: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# /usr/local/lib/python3.12/dist-packages/scanpy/tools/_rank_genes_groups.py:429: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "names"] = self.var_names[global_indices]
# /usr/local/lib/python3.12/dist-packages/scanpy/tools/_rank_genes_groups.py:431: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "scores"] = scores[global_indices]
# /usr/local/lib/python3.12/dist-packages/scanpy/tools/_rank_genes_groups.py:434: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals"] = pvals[global_indices]
# /usr/local/lib/python3.12/dist-packages/scanpy/tools/_rank_genes_groups.py:444: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals_adj"] = pvals_adj[global_indices]
# /usr/local/lib/python3.12/dist-packages/scanpy/tools/_rank_genes_groups.py:455: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# /usr/local/lib/python3.12/dist-packages/scanpy/tools/_rank_genes_groups.py:429: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "names"] = self.var_names[global_indices]
# /usr/local/lib/python3.12/dist-packages/scanpy/tools/_rank_genes_groups.py:431: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "scores"] = scores[global_indices]
# /usr/local/lib/python3.12/dist-packages/scanpy/tools/_rank_genes_groups.py:434: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals"] = pvals[global_indices]
# /usr/local/lib/python3.12/dist-packages/scanpy/tools/_rank_genes_groups.py:444: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals_adj"] = pvals_adj[global_indices]
# /usr/local/lib/python3.12/dist-packages/scanpy/tools/_rank_genes_groups.py:455: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# /usr/local/lib/python3.12/dist-packages/scanpy/tools/_rank_genes_groups.py:429: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "names"] = self.var_names[global_indices]
# /usr/local/lib/python3.12/dist-packages/scanpy/tools/_rank_genes_groups.py:431: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "scores"] = scores[global_indices]
# /usr/local/lib/python3.12/dist-packages/scanpy/tools/_rank_genes_groups.py:434: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals"] = pvals[global_indices]
# /usr/local/lib/python3.12/dist-packages/scanpy/tools/_rank_genes_groups.py:444: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals_adj"] = pvals_adj[global_indices]
# /usr/local/lib/python3.12/dist-packages/scanpy/tools/_rank_genes_groups.py:455: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# /usr/local/lib/python3.12/dist-packages/scanpy/tools/_rank_genes_groups.py:429: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "names"] = self.var_names[global_indices]
# /usr/local/lib/python3.12/dist-packages/scanpy/tools/_rank_genes_groups.py:431: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "scores"] = scores[global_indices]
# /usr/local/lib/python3.12/dist-packages/scanpy/tools/_rank_genes_groups.py:434: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals"] = pvals[global_indices]
# /usr/local/lib/python3.12/dist-packages/scanpy/tools/_rank_genes_groups.py:444: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals_adj"] = pvals_adj[global_indices]
# /usr/local/lib/python3.12/dist-packages/scanpy/tools/_rank_genes_groups.py:455: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# /usr/local/lib/python3.12/dist-packages/scanpy/tools/_rank_genes_groups.py:429: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "names"] = self.var_names[global_indices]
# /usr/local/lib/python3.12/dist-packages/scanpy/tools/_rank_genes_groups.py:431: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "scores"] = scores[global_indices]
# /usr/local/lib/python3.12/dist-packages/scanpy/tools/_rank_genes_groups.py:434: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals"] = pvals[global_indices]
# /usr/local/lib/python3.12/dist-packages/scanpy/tools/_rank_genes_groups.py:444: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals_adj"] = pvals_adj[global_indices]
# /usr/local/lib/python3.12/dist-packages/scanpy/tools/_rank_genes_groups.py:455: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# top-8 markers per astro subcluster:
#          0           1         2       3          4       5       6        7  \
# 0     XIST         UTY  SLC39A11     UTY  LINC00609  MT-CO3      F3    DPP10
# 1   SLC1A2      TTTY14     NEAT1  NLGN4Y      DCLK1  SNAP25   TPST1    WDR49
# 2    NRXN1       USP9Y      RORA  TTTY14       KAZN  MT-CO1   MACF1  ARHGEF4
# 3  CABLES1      NLGN4Y      XIST   USP9Y      DPP10  MT-CO2     DST     DPP6
# 4    NTRK2      SLC1A2      PFKP   GPM6A    L3MBTL4     CKB  SAMD4A    GRIA1
# 5    GPM6A  AC091826.2      MRAS   NRXN1       VCAN    SYT1  SLC1A3  SLC38A1
# 6     GPC5  AC002429.2   RPS6KA2   DNAH7   ADAMTSL3  MT-ND4  LRRC3B    SMAD9
# 7    LSAMP       NRXN1   RANBP3L  CTNNA2       CD44    NRGN     UTY    SNED1
#
#           8           9  ...        18         19        20          21  \
# 0  CNTNAP3B   PCDH9-AS2  ...   RANBP3L      SASH1    SORBS1         MT3
# 1    MT-ND4        DLC1  ...  SLC39A11     RASSF8     ADCY2       LRP1B
# 2    MT-CO3  AC008957.2  ...     NEAT1  LINC00472       FYN     PPP2R2B
# 3    MT-ND3  AC012404.1  ...      PFKP      NEAT1  ARHGEF10        PDK4
# 4    CHI3L1  AC093535.1  ...     SASH1      NPAS2     PLCG2  AC016831.7
# 5    AHCYL1     TMEM241  ...     SESN1       SOX5     FLRT2        XPO1
# 6        F3  AC093879.1  ...     MRPS6      MRPS6     PLCE1       TRPM3
# 7  RASGEF1B      P2RY14  ...     RIMS1      SSBP2     ERBIN       CADM2
#
#         22          23         24      25          26          27
# 0    NAMPT       NEAT1   CNTNAP3B   LSAMP   LINC00299        PFKP
# 1     ELL2       SASH1      HSPA5    RYR3  AC008957.2       NEAT1
# 2     CD44        SGCD     ATP1B2  SLC4A4      AHCYL1  AC016745.1
# 3    TPST1  AC016831.7     HSPA1A   PCDH9      SLC1A3      CHI3L1
# 4  ARHGEF3     PDE4DIP     MT-ND4  PTPRZ1       DPP10   LINC00299
# 5     TRIO     RANBP3L  NR2F2-AS1   NPAS3        FTH1      MALAT1
# 6    WWTR1        SOX5         F3  ADGRL3   DPP10-AS3        SMTN
# 7  ZFYVE28       MRPS6       UGP2   PDE4B      MALAT1       MRPS6
#
# [8 rows x 28 columns]
# [RAM] after subclustering     :   6.9 / 54.8 GB (14%)

# %% [markdown]
# > **Interpretation — astrocyte sub-clustering (5a).**
# >
# > Applying the §4a verdicts drops **6,488 cells** (3,526 + 1,996 + 966, exact) leaving **87,783 astrocytes** — and the 28 subsequent subcluster counts sum back to 87,783 exactly, confirming no cells were lost in the re-clustering. Leiden at resolution 1.0 on `X_scVI` gives **28 subclusters**, from cl0 (10,197 cells) down to cl27 (455). Resolution stability is **better than colab_07's microglia** (ARI 0.630 at res=0.5, 0.643 at res=1.5, vs microglia's 0.455/0.551) — a more discrete partition, though still not fully rigid; **subcluster numbers are not stable across runs** and should not be cited as fixed identities, same caveat as colab_07.
# >
# > **Study-purity is far more pervasive at this resolution than colab_05's coarser adjudication saw.** colab_05 flagged 4 of 8 top-level astrocyte clusters as study-pure; here, subclustering within the "clean" remainder reveals **22 of 28 subclusters (78.6%, confirmed numerically in §6b)** crossing the same donor/study dominance thresholds, several far more extreme than anything colab_05 saw at the top level: **cl19 (99.6% SEA-AD), cl26 (99.2%), cl27 (98.9%), cl20 (96.6%), cl21/23/24 (96.3–96.6% Li)**. These are the isolated "satellite" islands visible peeling off the main mass in the `leiden_astro` UMAP, and the `study_id` UMAP shows visible color-segregation in the same peripheral regions — a real spatial signature, not a table artifact.
# >
# > **Sex-linked genes dominate the DE of three of the four largest subclusters.** cl0 (top marker XIST), cl1 (UTY/TTTY14/USP9Y/NLGN4Y), cl3 (UTY/NLGN4Y/TTTY14/USP9Y) are all strongly Y-linked/XIST-driven. **cl2 is a correction from an earlier misreading** — its actual top-8 (SLC39A11/NEAT1/RORA/XIST/PFKP/MRAS/RPS6KA2/RANBP3L) has XIST only at rank 3 among otherwise non-sex genes, not the USP9Y/TTTY14 pair previously attributed to it (those belong to cl1/cl3) — so cl2 is only weakly sex-associated, not a fourth clean case. Together cl0/1/2/3 are **31,253 cells, over a third of the remaining astrocyte population**. This is the same nuisance-axis gap colab_07 found (sex slipping past a donor/study-only check) but at much larger scale than colab_07's minor sex-driven subclusters (5, 10) — resolved in §6a: all four land in the majority `resting` bucket, so no `NUISANCE_OVERRIDE` is triggered, but it means "resting" is not one uniform biological state either.
# >
# > The APOE UMAP shows no gross segregation — carrier/noncarrier/e2 are well-interleaved through the core, consistent with the colab_06 finding that APOE geometry is not recoverable at the integration level (expected, not a new concern).

# %% [markdown]
# ## 6 — Substate definition + integrity scan

# %% [markdown]
# ### 6a — Astrocyte substate axis: reactive / DAA (GFAP-high) vs resting (eval #1 label source)
#
# This closes the eval #1 OPEN item for astrocytes, using the **rebuilt** method colab_07 arrived at after the microglia DAM-argmax collapse — because the same trap is expected here. Canonical DAA (disease-associated astrocytes; Habib et al. 2020) was defined in mouse, and its signature mixes (i) **pan-astrocytic genes** that are high-and-flat in *every* astrocyte (AQP4, SLC1A3, ALDH1L1) with (ii) **mouse-specific or dropout genes** (Serpina3n has no clean 1:1 human ortholog at the count level; several DAA markers sit at dropout in this intersection snRNA set). An absolute `score_genes` argmax over that list would again produce an "is-an-astrocyte" score, not a substate axis.
#
# **The rebuilt axis (provisional gene lists, to validate against the dotplot on the first run).** The measurable reactive program here is **GFAP-high / DAA-like** (GFAP, CD44, VIM, CHI3L1, SERPINA3 — human reactive-astrocyte markers that should genuinely vary across subclusters) versus **resting** (SLC1A2, GLUL, GJA1, NRXN1 — homeostatic glutamate-handling / gap-junction genes that go *down* with reactivity and are well-detected). Three method choices, identical to colab_07: (1) trim to well-measured, discriminating genes only — drop pan-astrocytic inflators (AQP4, SLC1A3, ALDH1L1) and mouse/dropout genes; (2) **z-score each gene across all astrocytes** before pooling, so a constitutively-high gene cannot dominate its pole; (3) one **continuous axis** = mean(z, reactive) − mean(z, resting), with a band around zero for `intermediate`, instead of argmax of two non-comparable absolute scores. Labelled **"reactive," not "DAA,"** to avoid claiming a mouse template the data cannot support. Scored on raw-expression-derived lognorm, independent of any FM embedding, so the eval #1 probe against these labels stays non-circular.
#
# **First-run outcome.** The gene lists needed no rebuild — GFAP does show the pre-registered pan-astrocytic-inflation risk (flat-and-high across nearly every subcluster in the §6a dotplot), but z-scoring absorbs that and CD44/CHI3L1 carry the real discriminating signal. **SERPINA3, however, is genuinely absent from the object's `var_names`** (confirmed exact *and* case-insensitive in the §6a addendum, ruling out a lookup bug) — a real cross-study gene-intersection gap, not a fixable error; CHI3L1 alone carries the load-bearing reactive signal cleanly. `INT_MARGIN = 0.10` held without recalibration: the largest intermediate-band axis value and the smallest reactive/resting-pole value sit either side of it with a clear gap, the same "natural gap" validation colab_07 used. `NUISANCE_OVERRIDE` fired zero times — the sex-linked subclusters found in §5a's DE (0, 1, 3 — Y-linked/XIST genes; cl2 only weakly so, see §5a interp) all land in the majority `resting` bucket, the colab_07 cl5/cl12 pattern (lower stakes, low-cost to leave undocumented in the JSON), not the cl10 pattern (consequential bucket, needs correcting).
#
# **Four things carried into the interp (parallel to colab_07):**
#
# - **eval #1 must be donor-held-out.** If the reactive pole concentrates in donor/study-confounded subclusters (see §6b), a probe "win" on a non-donor-held-out split could be recovering donor/study, not substate. eval #1 already inherits the global donor-level 70/15/15 split (contract §Eval #1), and the per-subcluster `confounded` flag is written into the committed JSON.
# - **`INT_MARGIN = 0.10`** — validated by the observed axis distribution on this run (see above), not just an unvalidated guess going forward.
# - **Nuisance axes the donor/study check misses.** colab_07 found sex (Y-linked) and heat-shock subclusters slipping the donor/study threshold; cl42/cl45 (heat-shock / high-depth) are already dropped here, and the first run confirmed a similar sex-linked pattern recurs in astrocytes (subclusters 0/1/3) — but landing in the majority bucket, it does not require a `NUISANCE_OVERRIDE` entry.
# - **"reactive" is not one uniform program.** Distinct astrocyte reactive states — e.g. the metallothionein / oxidative-stress program (MT1G/MT2A/MT1E) and the complement / A1-like program (C3) — are **not** the same as the GFAP-high axis. `KNOWN_NUISANCE_UNCONFOUNDED` and `REACTIVE_BUCKET_NOTES` were deliberately left empty in the committed JSON — the qualitative content (which subclusters are sex-driven-but-clean, which reactive subcluster is the trustworthy anchor vs. which is confounded) lives in the §5a/§6a/§6b interpretation cells instead, since nothing downstream reads these two JSON fields programmatically.
#
# The signature lists, the excluded genes (with reason), the per-subcluster assignment + confound flags, any nuisance-override record, and the eval-design requirements are written to `outputs/astrocyte_substate_signatures.json` as the committed definition.

# %%
# Astrocyte substate axis (eval #1 label source) — built with the colab_07 rebuilt method from the
# start, because the microglia DAM failure mode is expected to recur for astrocyte DAA: canonical
# (mouse) DAA mixes pan-astrocytic genes (AQP4/SLC1A3/ALDH1L1, high-and-flat in ALL astrocytes) with
# mouse-only / dropout genes, so an absolute score_genes argmax would again be an "is-an-astrocyte"
# score. The measurable reactive program here is GFAP-high / DAA-like (GFAP/CD44/VIM/CHI3L1/SERPINA3,
# which should vary) vs resting (SLC1A2/GLUL/GJA1/NRXN1, well-detected, down with reactivity).
# Labeled "reactive" NOT "DAA" to avoid claiming a mouse template the data cannot support.
#
# Method (identical to colab_07 §6a): (1) trim to WELL-MEASURED, DISCRIMINATING genes; (2) z-score
# each gene across all astrocytes before pooling; (3) ONE continuous axis = mean(z,reactive) -
# mean(z,resting), band around 0 = "intermediate".
#
# PROVISIONAL (first-run): validate these lists against the 6a dotplot below. Any
# "reactive" gene high-and-flat everywhere is a pan-astrocytic inflator -> move to EXCLUDED_GENES;
# any listed gene at dropout -> drop. Do not trust the split until the dotplot confirms discrimination.
SUBSTATE_SIG = {
    "reactive": ["GFAP", "CD44", "VIM", "CHI3L1", "SERPINA3"],   # GFAP-high / DAA-like reactive
    "resting":  ["SLC1A2", "GLUL", "GJA1", "NRXN1"],             # homeostatic glutamate-handling
}
EXCLUDED_GENES = {  # written into the committed JSON so the exclusion is auditable
    "pan_astrocytic_inflators": ["AQP4", "SLC1A3", "ALDH1L1"],
    "mouse_only_or_dropout":    ["SERPINA3N", "C4B", "GBP2", "OSMR"],
}

sig_present = {k: [g for g in gs if g in astro.var_names] for k, gs in SUBSTATE_SIG.items()}
for k, gs in sig_present.items():
    # fail loud rather than silently scoring an empty pole
    assert gs, f"[substate] {k}: zero genes present in var_names — cannot score this pole"
    miss = set(SUBSTATE_SIG[k]) - set(gs)
    if miss:
        print(f"[substate] {k}: absent from gene set -> {sorted(miss)}")

# z-score each signature gene across ALL astrocytes on the lognorm layer, then pool
all_sig = sig_present["reactive"] + sig_present["resting"]
L = astro.layers["lognorm"][:, [astro.var_names.get_loc(g) for g in all_sig]]
L = L.toarray() if sp.issparse(L) else np.asarray(L)
Z = (L - L.mean(0)) / (L.std(0) + 1e-9)
zdf = pd.DataFrame(Z, columns=all_sig)

astro.obs["score_reactive"] = zdf[sig_present["reactive"]].mean(axis=1).values
astro.obs["score_resting"]  = zdf[sig_present["resting"]].mean(axis=1).values
astro.obs["substate_axis"]  = astro.obs["score_reactive"] - astro.obs["score_resting"]

SUB = astro.obs.groupby("leiden_astro", observed=True)[
    ["score_reactive", "score_resting", "substate_axis"]].mean()
print("per-subcluster mean substate scores (z-units) + axis:")
print(SUB.round(3))

# provisional substate per subcluster from the continuous axis. INT_MARGIN is in z-score units,
# an UNVALIDATED placeholder: calibrate ONCE post-run against the observed per-subcluster axis
# distribution (recorded in the interp), same "refine at pilot" pattern as colab_07 / the contract.
INT_MARGIN = 0.10
def _call(a):
    return "intermediate" if abs(a) < INT_MARGIN else ("reactive" if a > 0 else "resting")
sub_assign_axis_only = {cl: _call(row["substate_axis"]) for cl, row in SUB.iterrows()}

# Manual nuisance override (same precedent as colab_07 cl10 / CL44_VERDICT — recorded, not silent).
# EMPTY until the first run: the §6b donor/study check does not catch every nuisance axis (colab_07
# found sex + heat-shock subclusters slipping it). cl42/cl45 (heat-shock/high-depth) are already
# dropped in §5a, but the first run must inspect the DE for any sex/stress-driven subcluster landing
# in the REACTIVE pole (the consequential bucket) and re-bucket it here — do NOT pre-guess entries.
NUISANCE_OVERRIDE = {}   # e.g. {"<cl>": {"to": "intermediate", "reason": "..."}} after the first run
sub_assign = dict(sub_assign_axis_only)
for cl_key, ov in NUISANCE_OVERRIDE.items():
    matches = [cl for cl in sub_assign if str(cl) == cl_key]
    assert matches, f"[nuisance override] subcluster {cl_key!r} not found in this run's clusters"
    for cl in matches:
        print(f"[nuisance override] cl{cl_key}: axis-only call "
              f"{sub_assign_axis_only[cl]!r} -> {ov['to']!r} ({ov['reason']})")
        sub_assign[cl] = ov["to"]

# Nuisance subclusters that slip the donor/study check but land in the majority/default (resting)
# bucket — documented, not overridden (lower stakes: they dilute rather than manufacture a finding).
# Fill from the first-run DE, same as colab_07's cl5/cl12.
KNOWN_NUISANCE_UNCONFOUNDED = {}

# Heterogeneity WITHIN the "reactive" call (qualitative, from DE + the 6a dotplot) so a reader does
# not treat the bucket as one uniform program. Distinct astro reactive states (metallothionein/
# oxidative-stress MT1G/MT2A/MT1E; complement/A1-like C3) are NOT the GFAP-high axis — record as
# limitations / candidate separate labels. No code/labeling effect. Fill from the first run.
REACTIVE_BUCKET_NOTES = {}

astro.obs["substate"] = astro.obs["leiden_astro"].map(sub_assign)
# fail loud on any unmapped subcluster instead of letting .astype(str) mint a silent "nan" label
assert not astro.obs["substate"].isna().any(), "subcluster(s) missing a substate assignment"
astro.obs["substate"] = astro.obs["substate"].astype(str)
print("\nprovisional substate per subcluster (axis-only):", sub_assign_axis_only)
print("provisional substate per subcluster (after nuisance override):", sub_assign)
print("substate cell counts:", astro.obs["substate"].value_counts().to_dict())

# eval#1 leakage guard: record per-subcluster donor/study dominance next to each substate call so
# the interp can see whether the reactive pole is donor/study-confounded. eval#1 already inherits the
# global donor-held-out split (contract), but a reactive substate that is single-donor in the held-out
# set is unevaluable, not a win.
dom = []
for cl, idx in astro.obs.groupby("leiden_astro", observed=True).groups.items():
    o = astro.obs.loc[idx]
    td = float(o["donor_id"].value_counts(normalize=True).iloc[0])
    ts = float(o["study_id"].value_counts(normalize=True).iloc[0])
    dom.append({"subcluster": str(cl), "n": int(len(o)),
                "substate": sub_assign[cl], "axis_only_call": sub_assign_axis_only[cl],
                "axis": round(float(SUB.loc[cl, "substate_axis"]), 3),
                "top_donor_frac": round(td, 3), "top_study_frac": round(ts, 3),
                "confounded": bool(td >= 0.50 or ts >= 0.60)})
dom_df = pd.DataFrame(dom).set_index("subcluster")
print("\nper-subcluster substate + confound flags:")
print(dom_df)

# committed signature definition (eval#1 label source)
SIG_PATH = os.path.join(REPO_PATH, "outputs", "astrocyte_substate_signatures.json")
with open(SIG_PATH, "w") as f:
    json.dump({"date": TODAY, "lineage": "astrocyte",
               "axis": "reactive_DAA_GFAP_high_vs_resting",
               "scoring": "per-gene z-score across all astrocytes (lognorm); pole = mean z; "
                          "substate_axis = reactive - resting; cluster-level mean",
               "signatures": SUBSTATE_SIG, "present": sig_present,
               "excluded_genes": EXCLUDED_GENES,
               "intermediate_margin_zunits": INT_MARGIN,
               "per_subcluster": dom,
               "per_subcluster_assignment": sub_assign,
               "per_subcluster_assignment_axis_only": sub_assign_axis_only,
               "colab05_cluster_verdicts": ASTRO_CLUSTER_VERDICTS,
               "nuisance_override": NUISANCE_OVERRIDE,
               "known_nuisance_unconfounded": KNOWN_NUISANCE_UNCONFOUNDED,
               "reactive_bucket_heterogeneity_notes": REACTIVE_BUCKET_NOTES,
               "eval1_requirements": {
                   "labels": ["reactive", "resting", "intermediate"],
                   "donor_held_out": True,
                   "reason": "reactive pole may concentrate in donor/study-confounded subclusters "
                             "(see per_subcluster confounded flag); a non-donor-held-out probe could "
                             "recover donor/study, not substate"},
               "uncaptured_programs": {
                   "metallothionein_oxidative_stress": ["MT1G", "MT2A", "MT1E"],
                   "complement_A1_like": ["C3"],
                   "note": "distinct astrocyte reactive states not scored by the GFAP-high axis"},
               "note": "expression-signature substate labels for the eval#1 probe; independent of FM "
                       "embeddings (not circular). Built with the colab_07 rebuilt method (z-scored "
                       "continuous axis) from the start; canonical mouse-DAA not directly recoverable. "
                       "Gene lists PROVISIONAL pending first-run dotplot validation. colab_05 ambient "
                       "(cl22) + donor-effect (cl42/cl45) clusters dropped before subclustering."},
              f, indent=2)
print("saved substate definition ->", SIG_PATH)

# substate-axis UMAP (colors come from .obs — no .X swap needed); rendered inline AND saved
sc.pl.umap(astro, color=["score_reactive", "score_resting", "substate_axis", "substate"],
           show=False)
plt.savefig(os.path.join(FIG_DIR, "6a_substate_scores_umap.png"), dpi=150, bbox_inches="tight")
plt.show()  # render inline AND keep the saved PNG

# signature dotplot — used genes + the excluded context genes so the exclusion is visible
X_raw = astro.X
astro.X = astro.layers["lognorm"]
try:
    context = [g for g in (EXCLUDED_GENES["pan_astrocytic_inflators"]
                           + EXCLUDED_GENES["mouse_only_or_dropout"]) if g in astro.var_names]
    dot_genes = sig_present["reactive"] + sig_present["resting"] + context
    sc.pl.dotplot(astro, dot_genes, groupby="leiden_astro", standard_scale="var", show=False)
    plt.savefig(os.path.join(FIG_DIR, "6a_substate_signature_dotplot.png"), dpi=150, bbox_inches="tight")
    plt.show()  # render inline AND keep the saved PNG
finally:
    astro.X = X_raw
# Out:
# [substate] reactive: absent from gene set -> ['SERPINA3']
# per-subcluster mean substate scores (z-units) + axis:
#               score_reactive  score_resting  substate_axis
# leiden_astro
# 0                     -0.270          0.464         -0.734
# 1                     -0.372          0.360         -0.732
# 2                     -0.149          0.017         -0.166
# 3                     -0.156          0.374         -0.529
# 4                      0.402         -1.164          1.566
# 5                     -0.404         -0.086         -0.318
# 6                      0.195          0.125          0.070
# 7                      0.024         -0.370          0.394
# 8                      0.795          0.267          0.527
# 9                     -0.318          0.262         -0.580
# 10                     0.291          0.004          0.287
# 11                     0.286         -0.405          0.691
# 12                     0.588         -1.059          1.647
# 13                    -0.202         -0.235          0.033
# 14                    -0.392          0.329         -0.721
# 15                     0.073          0.355         -0.282
# 16                     0.237          0.308         -0.071
# 17                    -0.114          0.290         -0.405
# 18                     0.073          0.162         -0.089
# 19                     0.172         -0.231          0.403
# 20                     0.192         -0.318          0.511
# 21                    -0.483          0.355         -0.838
# 22                     1.063         -0.885          1.948
# 23                    -0.017          0.026         -0.043
# 24                     0.596          0.425          0.171
# 25                     0.594          0.109          0.485
# 26                     0.521         -0.377          0.898
# 27                     0.445         -0.360          0.804
#
# provisional substate per subcluster (axis-only): {'0': 'resting', '1': 'resting', '2': 'resting', '3': 'resting', '4': 'reactive', '5': 'resting', '6': 'intermediate', '7': 'reactive', '8': 'reactive', '9': 'resting', '10': 'reactive', '11': 'reactive', '12': 'reactive', '13': 'intermediate', '14': 'resting', '15': 'resting', '16': 'intermediate', '17': 'resting', '18': 'intermediate', '19': 'reactive', '20': 'reactive', '21': 'resting', '22': 'reactive', '23': 'intermediate', '24': 'reactive', '25': 'reactive', '26': 'reactive', '27': 'reactive'}
# provisional substate per subcluster (after nuisance override): {'0': 'resting', '1': 'resting', '2': 'resting', '3': 'resting', '4': 'reactive', '5': 'resting', '6': 'intermediate', '7': 'reactive', '8': 'reactive', '9': 'resting', '10': 'reactive', '11': 'reactive', '12': 'reactive', '13': 'intermediate', '14': 'resting', '15': 'resting', '16': 'intermediate', '17': 'resting', '18': 'intermediate', '19': 'reactive', '20': 'reactive', '21': 'resting', '22': 'reactive', '23': 'intermediate', '24': 'reactive', '25': 'reactive', '26': 'reactive', '27': 'reactive'}
# substate cell counts: {'resting': 48147, 'reactive': 28465, 'intermediate': 11171}
#
# per-subcluster substate + confound flags:
#                 n      substate axis_only_call   axis  top_donor_frac  \
# subcluster
# 0           10197       resting        resting -0.734           0.082
# 1            7144       resting        resting -0.732           0.126
# 2            7026       resting        resting -0.166           0.232
# 3            6886       resting        resting -0.529           0.223
# 4            6242      reactive       reactive  1.566           0.085
# 5            5773       resting        resting -0.318           0.140
# 6            4041  intermediate   intermediate  0.070           0.382
# 7            3830      reactive       reactive  0.394           0.058
# 8            3494      reactive       reactive  0.527           0.244
# 9            3355       resting        resting -0.580           0.201
# 10           3334      reactive       reactive  0.287           0.274
# 11           3285      reactive       reactive  0.691           0.254
# 12           3255      reactive       reactive  1.647           0.143
# 13           2655  intermediate   intermediate  0.033           0.500
# 14           2329       resting        resting -0.721           0.717
# 15           2271       resting        resting -0.282           0.544
# 16           2265  intermediate   intermediate -0.071           0.341
# 17           2244       resting        resting -0.405           0.368
# 18           1557  intermediate   intermediate -0.089           0.429
# 19           1136      reactive       reactive  0.403           0.981
# 20           1091      reactive       reactive  0.511           0.928
# 21            922       resting        resting -0.838           0.577
# 22            700      reactive       reactive  1.948           0.546
# 23            653  intermediate   intermediate -0.043           0.868
# 24            619      reactive       reactive  0.171           0.939
# 25            543      reactive       reactive  0.485           0.606
# 26            481      reactive       reactive  0.898           0.960
# 27            455      reactive       reactive  0.804           0.985
#
#             top_study_frac  confounded
# subcluster
# 0                    0.490       False
# 1                    0.500       False
# 2                    0.761        True
# 3                    0.494       False
# 4                    0.599       False
# 5                    0.825        True
# 6                    0.807        True
# 7                    0.713        True
# 8                    0.946        True
# 9                    0.758        True
# 10                   0.765        True
# 11                   0.439       False
# 12                   0.747        True
# 13                   0.518        True
# 14                   0.879        True
# 15                   0.880        True
# 16                   0.460       False
# 17                   0.838        True
# 18                   0.761        True
# 19                   0.996        True
# 20                   0.966        True
# 21                   0.965        True
# 22                   0.803        True
# 23                   0.963        True
# 24                   0.966        True
# 25                   0.634        True
# 26                   0.992        True
# 27                   0.989        True
# saved substate definition -> /content/ad-glia-fm-prep/outputs/astrocyte_substate_signatures.json

# %% [markdown]
# > **Interpretation — substate axis: reactive vs resting (6a).**
# >
# > The panel needed no rebuild, but one gene didn't survive contact with the data: `SERPINA3` prints as **absent from the gene set** — confirmed genuinely absent (not a lookup bug) in the §6a addendum below. CHI3L1, the other load-bearing reactive gene, is intact and does real work in the dotplot: it's cleanly elevated in the highest-axis subclusters (8, 19, 22, 24, 25) and low in resting ones. **GFAP shows the pre-registered pan-astrocytic-inflation risk** — large/dark across nearly every row including resting-labeled subclusters 0–3 — so the real discriminating power in this axis comes from **CD44** (which tracks the axis cleanly: large dots exactly at the highest-axis subclusters 4, 8, 12, 22, 24, 25) and CHI3L1, not GFAP. Two of the excluded-context genes plotted for visibility, **C4B and GBP2, are essentially dead weight** — near-zero expression and fraction across almost every subcluster — contributing close to nothing to the composite score despite being shown.
# >
# > **The 3-way split is non-degenerate: resting 48,147 / reactive 28,465 / intermediate 11,171** (sums to 87,783, no cells lost). `INT_MARGIN = 0.10` lands in a genuine natural gap — the largest intermediate-band axis value is cl18 at **|0.089|**, the nearest reactive/resting-pole value is cl2 at **|0.166|** — the same "natural gap" validation colab_07 used, so the placeholder margin is retained rather than re-tuned.
# >
# > **The reactive bucket is heavily confounded — 11 of 13 reactive subclusters (84.6%) are donor/study-flagged** (confirmed in detail in §6b); only **cl4 (n=6,242)** and **cl11 (n=3,285)** are clean, together **9,527 of 28,465 reactive cells (33.5%)** — so roughly two-thirds of "reactive" cells sit in confounded subclusters, closely matching colab_07's microglia "activated" bucket (~69% confounded) — the anticipated failure mode recurring at similar magnitude, not a new problem. **cl4 is the primary generalizable anchor** (the colab_07 cl6 analog) — its DE markers (NTRK2, SLC1A2, PFKP, GPM6A, CKB, GRIA1) look like plausible real astrocyte biology, not technical markers. Worth flagging: cl4's `top_study_frac` is **0.599**, just 0.001 under the 0.60 confound threshold — it clears "unconfounded" on a technicality, so it shouldn't be leaned on as strongly as cl11 (study 0.439, genuinely un-dominated) if eval#1 needs a single cleanest case. The four-panel UMAP shows the reactive label (orange) concentrating in the same peripheral/satellite regions §5a already flagged as near-single-study — visually consistent with the confound finding, not contradicting it.

# %% [markdown]
#   ### 6a (addendum) — Verify SERPINA3 absence from the reactive panel
#
#   §6a's fail-loud check reported `SERPINA3` as absent from the astrocyte object's gene set when
#   building the reactive signature score. Before treating that as a settled substrate fact, this
#   cell distinguishes a genuine cross-study gene-intersection gap from a `var_names` lookup bug
#   (case, alias, whitespace) — the same distinction that mattered for the colab_06 string-key
#   incident. A case-insensitive scan runs alongside the exact match specifically to catch a
#   mismatch the exact-string check alone would miss.

# %%
print("SERPINA3 in var_names:", "SERPINA3" in astro.var_names)
print("case-insensitive matches:", [g for g in astro.var_names if g.upper() == "SERPINA3"])
# Out:
# SERPINA3 in var_names: False
# case-insensitive matches: []

# %% [markdown]
# > **Interpretation — SERPINA3 verification (6a addendum).**
# >
# > Both checks come back empty: `SERPINA3 in var_names` is `False`, and the case-insensitive scan finds no alias match either. This rules out a lookup bug (case, whitespace, alternate symbol) — SERPINA3 is genuinely not part of the cross-study gene intersection this object carries. Nothing to fix; the gap is a data fact, documented in `What we did.txt` and carried as a limitation into the eval#1 label definition. CHI3L1 remains the intact, load-bearing reactive discriminator (§6a).

# %% [markdown]
# ### 6b — Per-subcluster integrity scan (donor / study / ambient)
#
# The same lighter scan as colab_07 §6b. colab_05 already ran the heavy six-lever battery on the astrocytes (that is what produced the cluster verdicts applied in §4a), so here we **report** per-subcluster diagnostics on the *new* sub-clustering — dominant-donor fraction, dominant-study fraction, median counts / mito, and an ambient/doublet proxy (oligo / microglia / neuron marker leakage) — without re-running a gated 2nd-scVI. A subcluster that is donor-dominated (≥ 50%) or study-dominated (≥ 60%) is flagged for the interp; because cl33 was kept as `real_confounded`, its descendant subcluster(s) are expected to re-flag here and that is by design (documented, not evaluated as a generalizable win). The gated 2nd-scVI is run **only** if a flagged subcluster also turns out to carry the APOE signal eval #2 depends on.

# %%
# lighter integrity scan: per-subcluster donor/study dominance + ambient/quality proxies
X_raw = astro.X
if "pct_counts_mt" not in astro.obs.columns or "total_counts" not in astro.obs.columns:
    astro.var["mt"] = astro.var_names.str.startswith("MT-")
    sc.pp.calculate_qc_metrics(astro, qc_vars=["mt"], inplace=True, percent_top=None, log1p=False)

# off-lineage ambient proxy for astrocytes: oligo + microglia + neuron markers
AMBIENT = [g for g in ["MBP","PLP1","MOBP","CSF1R","P2RY12","AIF1","SNAP25","RBFOX3"]
           if g in astro.var_names]
astro.X = astro.layers["lognorm"]
try:
    sc.tl.score_genes(astro, gene_list=AMBIENT, score_name="score_ambient", use_raw=False)
finally:
    astro.X = X_raw

rows = []
for cl, idx in astro.obs.groupby("leiden_astro", observed=True).groups.items():
    o = astro.obs.loc[idx]
    rows.append({
        "subcluster": cl, "n": len(o),
        "top_donor_frac": round(float(o["donor_id"].value_counts(normalize=True).iloc[0]), 3),
        "top_study_frac": round(float(o["study_id"].value_counts(normalize=True).iloc[0]), 3),
        "median_counts": int(o["total_counts"].median()),
        "median_pct_mt": round(float(o["pct_counts_mt"].median()), 2),
        "mean_ambient": round(float(o["score_ambient"].mean()), 3),
    })
scan = pd.DataFrame(rows).set_index("subcluster")
DONOR_FLAG, STUDY_FLAG = 0.50, 0.60
scan["flag"] = np.where(scan["top_donor_frac"] >= DONOR_FLAG, "donor",
                np.where(scan["top_study_frac"] >= STUDY_FLAG, "study", ""))
print("per-subcluster integrity scan:")
with pd.option_context("display.width", 160):
    print(scan)
flagged = scan[scan["flag"] != ""]
if len(flagged):
    print(f"\n[FLAG] {len(flagged)} subcluster(s) donor/study-dominated — report in interp; "
          f"gated 2nd-scVI ONLY if a flagged cluster also carries the eval#2 APOE signal:")
    print(flagged)
else:
    print("\nno subcluster donor/study-dominated above thresholds — astrocyte substrate clean")
# Out:
# per-subcluster integrity scan:
#                 n  top_donor_frac  top_study_frac  median_counts  median_pct_mt  mean_ambient   flag
# subcluster
# 0           10197           0.082           0.490           7870           0.18        -0.022
# 1            7144           0.126           0.500           6840           0.10         0.035
# 2            7026           0.232           0.761           8235           0.16        -0.043  study
# 3            6886           0.223           0.494           8407           0.28        -0.033
# 4            6242           0.085           0.599           5777           0.13         0.012
# 5            5773           0.140           0.825           1570           0.64         0.238  study
# 6            4041           0.382           0.807           7865           0.10        -0.063  study
# 7            3830           0.058           0.713           5889           0.12        -0.008  study
# 8            3494           0.244           0.946           7661           0.77        -0.006  study
# 9            3355           0.201           0.758           8907           0.06        -0.034  study
# 10           3334           0.274           0.765           8648           0.04        -0.037  study
# 11           3285           0.254           0.439           4994           0.32        -0.020
# 12           3255           0.143           0.747           6886           0.06        -0.019  study
# 13           2655           0.500           0.518           6978           0.14        -0.063  donor
# 14           2329           0.717           0.879          13652           0.43        -0.092  donor
# 15           2271           0.544           0.880           6736           0.93        -0.080  donor
# 16           2265           0.341           0.460           7887           0.33        -0.024
# 17           2244           0.368           0.838           6642           0.04        -0.019  study
# 18           1557           0.429           0.761           8687           0.48         0.003  study
# 19           1136           0.981           0.996           5953           0.76         0.038  donor
# 20           1091           0.928           0.966          10605           0.10        -0.088  donor
# 21            922           0.577           0.965           5786           0.32         0.093  donor
# 22            700           0.546           0.803           8657           0.05        -0.008  donor
# 23            653           0.868           0.963           2949           0.23         0.191  donor
# 24            619           0.939           0.966          11728           0.91        -0.091  donor
# 25            543           0.606           0.634          15604           0.13        -0.095  donor
# 26            481           0.960           0.992          11096           0.02        -0.068  donor
# 27            455           0.985           0.989          16169           0.02        -0.044  donor
#
# [FLAG] 22 subcluster(s) donor/study-dominated — report in interp; gated 2nd-scVI ONLY if a flagged cluster also carries the eval#2 APOE signal:
#                n  top_donor_frac  top_study_frac  median_counts  \
# subcluster
# 2           7026           0.232           0.761           8235
# 5           5773           0.140           0.825           1570
# 6           4041           0.382           0.807           7865
# 7           3830           0.058           0.713           5889
# 8           3494           0.244           0.946           7661
# 9           3355           0.201           0.758           8907
# 10          3334           0.274           0.765           8648
# 12          3255           0.143           0.747           6886
# 13          2655           0.500           0.518           6978
# 14          2329           0.717           0.879          13652
# 15          2271           0.544           0.880           6736
# 17          2244           0.368           0.838           6642
# 18          1557           0.429           0.761           8687
# 19          1136           0.981           0.996           5953
# 20          1091           0.928           0.966          10605
# 21           922           0.577           0.965           5786
# 22           700           0.546           0.803           8657
# 23           653           0.868           0.963           2949
# 24           619           0.939           0.966          11728
# 25           543           0.606           0.634          15604
# 26           481           0.960           0.992          11096
# 27           455           0.985           0.989          16169
#
#             median_pct_mt  mean_ambient   flag
# subcluster
# 2                    0.16        -0.043  study
# 5                    0.64         0.238  study
# 6                    0.10        -0.063  study
# 7                    0.12        -0.008  study
# 8                    0.77        -0.006  study
# 9                    0.06        -0.034  study
# 10                   0.04        -0.037  study
# 12                   0.06        -0.019  study
# 13                   0.14        -0.063  donor
# 14                   0.43        -0.092  donor
# 15                   0.93        -0.080  donor
# 17                   0.04        -0.019  study
# 18                   0.48         0.003  study
# 19                   0.76         0.038  donor
# 20                   0.10        -0.088  donor
# 21                   0.32         0.093  donor
# 22                   0.05        -0.008  donor
# 23                   0.23         0.191  donor
# 24                   0.91        -0.091  donor
# 25                   0.13        -0.095  donor
# 26                   0.02        -0.068  donor
# 27                   0.02        -0.044  donor

# %% [markdown]
# > **Interpretation — per-subcluster integrity scan (6b).**
# >
# > **22 of 28 subclusters (78.6%) flag** on the standard donor ≥ 0.50 / study ≥ 0.60 check — a higher fraction than colab_07's microglia precedent (61%), confirming the extent already visible in §5a's study crosstab, now with real donor fractions added. Within the reactive bucket specifically: **11 of 13 reactive subclusters (84.6%) flagged**; only cl4 and cl11 clean, matching §6a's confound accounting exactly.
# >
# > **cl5 stands out on QC grounds independent of donor/study** — its median depth is **1,570 counts**, drastically below every other subcluster (the next-lowest is cl23 at 2,949; most others sit in the 5,000–16,000 range), and its ambient score is **0.238**, the highest of all 28 subclusters (next-highest is cl23 at 0.191). This combination — low depth + elevated off-lineage ambient signal — is the same signature that got the top-level cl22 dropped in §4a. Unlike cl22/42/45, though, cl5 is **not single-donor** (top_donor_frac = 0.140, spread across many donors, mostly Li at 0.825 study fraction) — it reads as a real multi-donor low-quality tail rather than a discrete contaminating event. It lands in the `resting` bucket (§6a), so it doesn't corrupt the reactive-pole confound story; its disposition is decided separately in §6d (kept, documented as a QC caveat).
# >
# > **A second pattern worth naming: several of the most donor-pure subclusters are also the deepest-sequenced** — cl14 (13,652 counts), cl20 (10,605), cl24 (11,728), cl25 (15,604), cl26 (11,096), cl27 (16,169) are six of the highest-depth subclusters in the set, and five of six (all but cl14) land in `reactive`. This raised the concern that sequencing depth, not donor/study composition, might be inflating the reactive score — tested directly and refuted in §6c.
# >
# > The `[FLAG]` block prints the same 22 flagged subclusters as a table for the audit trail; the gated 2nd-scVI is **not** triggered — that gate is reserved for a flagged subcluster that also carries the eval#2 APOE signal, which this lighter scan does not test.

# %% [markdown]
# ### 6c — Depth-vs-reactive-axis confound check
#
# §6b's per-subcluster QC columns show several of the most donor-pure subclus
# ters (20/24/25/26/27) sitting at unusually high sequencing depth — echoing
# the same "high-depth technical" mechanism colab_05 used to characterize cl4
# 5 at the top level. `normalize_total` corrects raw library-size differences
# but not depth-dependent dropout in lowly-expressed genes, so a lowly-expre
# ssed reactive marker (CD44/CHI3L1) could register as more strongly "reactiv
# e" simply because a deep-sequenced subcluster detects it more reliably — a
# technical confound distinct from the donor/study dominance §6b already flag
# s. This cell tests that hypothesis directly rather than inferring it from a
# handful of extreme subclusters: it joins §6a's per-subcluster `substate_ax
# is` with §6b's per-subcluster `median_counts`, reports the Pearson correlat
# ion across all subclusters, and plots the labeled scatter.

# %%
depth_axis = SUB[["substate_axis"]].join(scan[["median_counts", "top_donor_frac", "top_study_frac"]])
assert not depth_axis.isna().any().any(), "index mismatch between SUB (6a) and scan (6b)"

r = depth_axis["substate_axis"].corr(depth_axis["median_counts"])
print(f"Pearson r (substate_axis vs median_counts, n={len(depth_axis)} subclusters): {r:.3f}")
print(depth_axis.sort_values("median_counts"))

plt.figure(figsize=(5, 4))
plt.scatter(depth_axis["median_counts"], depth_axis["substate_axis"])
for cl, row in depth_axis.iterrows():
    plt.annotate(cl, (row["median_counts"], row["substate_axis"]), fontsize=7)
plt.axhline(0, color="grey", lw=0.5)
plt.xlabel("subcluster median_counts")
plt.ylabel("substate_axis (reactive - resting, z-units)")
plt.title("Depth vs reactive/resting axis, per astro subcluster")
plt.show()
# Out:
# Pearson r (substate_axis vs median_counts, n=28 subclusters): 0.114
#               substate_axis  median_counts  top_donor_frac  top_study_frac
# leiden_astro
# 5                 -0.318304           1570           0.140           0.825
# 23                -0.042514           2949           0.868           0.963
# 11                 0.691367           4994           0.254           0.439
# 4                  1.566058           5777           0.085           0.599
# 21                -0.837743           5786           0.577           0.965
# 7                  0.393790           5889           0.058           0.713
# 19                 0.402895           5953           0.981           0.996
# 17                -0.404550           6642           0.368           0.838
# 15                -0.281722           6736           0.544           0.880
# 1                 -0.731770           6840           0.126           0.500
# 12                 1.647067           6886           0.143           0.747
# 13                 0.033190           6978           0.500           0.518
# 8                  0.527207           7661           0.244           0.946
# 6                  0.070465           7865           0.382           0.807
# 0                 -0.734009           7870           0.082           0.490
# 16                -0.071164           7887           0.341           0.460
# 2                 -0.166016           8235           0.232           0.761
# 3                 -0.529395           8407           0.223           0.494
# 10                 0.286956           8648           0.274           0.765
# 22                 1.948207           8657           0.546           0.803
# 18                -0.088886           8687           0.429           0.761
# 9                 -0.579856           8907           0.201           0.758
# 20                 0.510664          10605           0.928           0.966
# 26                 0.897613          11096           0.960           0.992
# 24                 0.170628          11728           0.939           0.966
# 14                -0.720928          13652           0.717           0.879
# 25                 0.485072          15604           0.606           0.634
# 27                 0.804308          16169           0.985           0.989

# %% [markdown]
# > **Interpretation — depth-vs-reactive-axis confound check (6c).**
# >
# > **Pearson r = 0.114** across all 28 subclusters — negligible. The scatter makes the refutation visible directly: the three most reactive subclusters (**cl4, cl12, cl22**) sit at *moderate* depth (5,777–8,657 counts), not the highest, while **cl14** — the third-deepest subcluster in the entire set (13,652 counts, behind cl27's 16,169 and cl25's 15,604) — is one of the most strongly *resting* points on the plot (axis −0.72). If depth-dependent dropout were systematically inflating the reactive score, cl14 is exactly the case that should contradict it, and it does. The pattern flagged in §6b (5 of 6 deepest subclusters landing reactive) doesn't generalize across all 28 points — a small-sample coincidence, not a real trend.
# >
# > **Conclusion: the donor/study confound documented in §6b is a genuine composition effect, not a generic sequencing-depth artifact.** No depth-regression fix is warranted; the donor-held-out eval#1 requirement (already specified) remains the correct mitigation.

# %% [markdown]
#   ### 6d — Document the cl5 QC/ambient caveat (keep, not drop)
#
#   cl5 (n=5,773; median_counts=1,570, mean_ambient=0.238 — both the most extreme values of any
#   astrocyte subcluster) was evaluated as a drop candidate against the cl22/42/45 precedent from
#   §4a/§5a. Unlike those three, cl5 is not dominated by a single donor (top_donor_frac=0.140) — it
#   is a low-depth, elevated-ambient tail spread across many (mostly Li) donors, closer to a real
#   population tail than a discrete single-source artifact, and it clears the project's own
#   pre-registered secondary QC floor (500 counts / 250 genes). Decision: **keep** cl5 in the CPT
#   substrate — it lands in the low-stakes `resting` bucket, and CPT on raw counts tolerates a
#   noisier depth-tail far better than a supervised probe would — but record it as a documented
#   caveat rather than silently folding it in, so it stays visible to anyone reading the substate
#   definition later. This cell appends that caveat to the already-saved
#   `astrocyte_substate_signatures.json` rather than re-running §6a.

# %%
QC_CAVEATS = {
    "5": {
        "issue": "low-depth, elevated-ambient tail",
        "n": 5773,
        "median_counts": 1570,
        "mean_ambient": 0.238,
        "top_donor_frac": 0.140,
        "top_study_frac": 0.825,
        "substate": "resting",
        "decision": "keep",
        "reason": "not single-donor (unlike the cl22/42/45 precedent) -- spread across many donors, "
                  "closer to a real population tail than a discrete technical artifact; clears the "
                  "project's pre-registered QC floor (500 counts / 250 genes); lands in the low-stakes "
                  "resting bucket; CPT on raw counts tolerates a noisier depth-tail far better than a "
                  "supervised probe would.",
    }
}

with open(SIG_PATH) as f:
    sig = json.load(f)
sig["qc_caveats"] = QC_CAVEATS
with open(SIG_PATH, "w") as f:
    json.dump(sig, f, indent=2)
print("qc_caveats appended ->", SIG_PATH)
print(json.dumps(QC_CAVEATS, indent=2))
# Out:
# qc_caveats appended -> /content/ad-glia-fm-prep/outputs/astrocyte_substate_signatures.json
# {
#   "5": {
#     "issue": "low-depth, elevated-ambient tail",
#     "n": 5773,
#     "median_counts": 1570,
#     "mean_ambient": 0.238,
#     "top_donor_frac": 0.14,
#     "top_study_frac": 0.825,
#     "substate": "resting",
#     "decision": "keep",
#     "reason": "not single-donor (unlike the cl22/42/45 precedent) -- spread across many donors, closer to a real population tail than a discrete technical artifact; clears the project's pre-registered QC floor (500 counts / 250 genes); lands in the low-stakes resting bucket; CPT on raw counts tolerates a noisier depth-tail far better than a supervised probe would."
#   }
# }

# %% [markdown]
# > **Interpretation — cl5 QC caveat, keep decision (6d).**
# >
# > cl5 was evaluated as a drop candidate against the cl22/42/45 precedent and **kept**. The decisive difference from those three: cl22/42/45 were each ~98–99% one donor or study — a discrete artifact from one narrow source — while cl5 is spread across many donors (top_donor_frac 0.140), reading as a real low-quality tail of the population rather than a contaminating event, and it clears the project's own pre-registered secondary QC floor (500 counts / 250 genes). Dropping it now, on a threshold nobody pre-committed to, would be exactly the kind of after-the-fact justification the no-retro-ratcheting rule exists to prevent. The decision is recorded as a `qc_caveats` entry appended directly to the already-saved `astrocyte_substate_signatures.json` (visible to anyone reading the committed substate definition later) rather than silently folded into the `resting` bucket.

# %% [markdown]
# ## 7 — Save + handoff

# %% [markdown]
# ### 7a — Save astrocyte subset with substate labels; audit trace; commit instructions
#
# Save the astrocyte subset (raw counts in `.X` for the FM substrate, plus `leiden_astro`, `substate`, and the carried-over `apoe_carrier` / donor / study metadata) to Drive; the working `lognorm` layer is dropped before saving (rebuildable, keeps the file small). Append an `astrocyte_subset` trace to the cumulative `audit_report.json` and print the WSL commit commands. Committable = env freeze + audit JSON + the substate-signature JSON; the h5ad and figures are Drive- / gitignore-only.

# %%
import shlex
# cluster dispositions (drop cl22/cl42/cl45, keep cl33) were already applied in §5a — no membership
# change is needed here; the verdicts are recorded in the audit trace below.

ASTRO_DIR = os.path.join(DRIVE_ROOT, "astro_subset")
os.makedirs(ASTRO_DIR, exist_ok=True)
if "lognorm" in astro.layers:
    del astro.layers["lognorm"]                       # rebuildable; .X stays raw counts
if sp.issparse(astro.X) and astro.X.getformat() != "csr":
    astro.X = sp.csr_matrix(astro.X)
ASTRO_PATH = os.path.join(ASTRO_DIR, "astro_subset.h5ad")
astro.write_h5ad(ASTRO_PATH)
print("saved astrocyte subset ->", ASTRO_PATH, f"({os.path.getsize(ASTRO_PATH)/1e9:.2f} GB)")

AUDIT_REPORT_PATH = os.path.join(REPO_PATH, "outputs", "audit_report.json")
with open(AUDIT_REPORT_PATH) as f:
    report = json.load(f)
report["astrocyte_subset"] = {
    "status": "computed",
    "date": TODAY,
    "n_astrocytes": int(astro.n_obs),
    "n_subclusters": int(astro.obs["leiden_astro"].nunique()),
    "subcluster_on": "X_scVI",
    "substate_axis": "reactive_DAA_GFAP_high_vs_resting",
    "substate_counts": astro.obs["substate"].value_counts().to_dict(),
    "substate_signatures_file": os.path.relpath(SIG_PATH, REPO_PATH),
    "colab05_cluster_verdicts": ASTRO_CLUSTER_VERDICTS,
}
with open(AUDIT_REPORT_PATH, "w") as f:
    json.dump(report, f, indent=2)
print("audit trace appended ->", AUDIT_REPORT_PATH)

rel = [os.path.relpath(p, REPO_PATH) for p in (FREEZE_PATH, ENV_JSON_PATH, AUDIT_REPORT_PATH, SIG_PATH)]
print("\n=== Commit + push (from WSL — Colab has no git creds) ===")
print("  cd /mnt/c/Users/micic/ad-glia-fm-prep && git add " + " ".join(shlex.quote(r) for r in rel))
print("  cd /mnt/c/Users/micic/ad-glia-fm-prep && git commit -m "
      "'colab_08: astrocyte subset — colab_05 verdict application, subclustering, reactive-vs-resting substate'")
print("  cd /mnt/c/Users/micic/ad-glia-fm-prep && git push")
# Out:
# saved astrocyte subset -> /content/drive/MyDrive/ad-glia-fm-prep/astro_subset/astro_subset.h5ad (2.25 GB)
# audit trace appended -> /content/ad-glia-fm-prep/outputs/audit_report.json
#
# === Commit + push (from WSL — Colab has no git creds) ===
#   cd /mnt/c/Users/micic/ad-glia-fm-prep && git add outputs/software_versions/colab_08_2026-07-02_pip_freeze.txt outputs/software_versions/colab_08_2026-07-02_env.json outputs/audit_report.json outputs/astrocyte_substate_signatures.json
#   cd /mnt/c/Users/micic/ad-glia-fm-prep && git commit -m 'colab_08: astrocyte subset — colab_05 verdict application, subclustering, reactive-vs-resting substate'
#   cd /mnt/c/Users/micic/ad-glia-fm-prep && git push

# %% [markdown]
# > **Interpretation — save + handoff (7a).**
# >
# > The astrocyte subset is frozen for the FM notebooks: **`astro_subset.h5ad` (2.25 GB)** written to Drive with `.X` as raw counts (the rebuildable `lognorm` layer deleted, matrix forced to CSR for storage). The saved object carries `leiden_astro`, the `substate` labels (resting 48,147 / reactive 28,465 / intermediate 11,171), and the carried-over donor/study/APOE metadata. The audit trace appended to `audit_report.json` records the substate axis, counts, and the colab_05 cluster verdicts; the eval#1 confound requirements and the cl5 QC caveat live in `astrocyte_substate_signatures.json`. Commit/push commands printed for WSL (Colab has no git credentials) — committed as `45b60a0` (outputs) and `c60d8ab` (notebook + `_OUTPUT`). **Handoff:** this object plus the substate definition is the eval#1 label source for astrocytes — the reactive-bucket confound and the donor-held-out requirement travel with it, same as microglia.

# %% [markdown]
# ### Carried forward to the FM notebooks
#
# - **Astrocyte subset** (`astro_subset.h5ad`, raw genes) — the astrocyte CPT substrate and the eval #1 / eval #2 astrocyte working set (colab_05 ambient cl22 + donor-effect cl42/cl45 dropped; cl33 kept + flagged; cl5, a multi-donor low-depth/elevated-ambient tail, kept and documented as a QC caveat — see §6d).
# - **Substate labels** (`substate`: reactive / resting / intermediate) + their committed signature definition (`astrocyte_substate_signatures.json`) — the eval #1 label source for astrocytes. The axis is **reactive / DAA (GFAP-high) vs resting** (not canonical mouse DAA — see §6a); the gene panel needed no rebuild but SERPINA3 is confirmed genuinely absent from the gene intersection (§6a addendum). eval #1 uses the **global donor-held-out split** — the reactive pole is donor/study-confounded more extensively than colab_07's microglia precedent (84.6% of reactive subclusters flagged in §6b), though a depth-based confound was tested and refuted (§6c, Pearson r = 0.11).
# - **Cluster dispositions** — cl22/cl42/cl45 dropped, cl33 kept + flagged, cl5 kept + flagged as a QC caveat; recorded in the audit trace.
# - **eval #1 label source now COMPLETE for both lineages** — microglia (activated/homeostatic, colab_07) + astrocyte (reactive/resting, colab_08). The eval #1 substate linear probe can now be built. **Next: the FM notebooks** — zero-shot embedding (Geneformer + scGPT) on the two subsets, then CPT + PEFT across the three regimes, evaluated against these committed substate labels and the APOE axis.
