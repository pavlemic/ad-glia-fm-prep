# %% [markdown]
# # Diagnostic — colab_11 CPT came back INERT (held-out drift 0.0057 << 0.05 gate)
#
# colab_11's runtime is gone and the notebook is frozen; this is a standalone read-only diagnostic that works from the **saved artifacts on Drive** only. It does not re-run any part of the pipeline and produces no committed output.
#
# The near-zero drift has three candidate explanations, which need different responses:
#
# 1. **Genuine null** — the LoRA update is honest but barely moves the pooled embedding.
# 2. **Undertrained** — attention-only r=8 over ~0.67 epoch is too weak a perturbation.
# 3. **Silent mechanical failure** — gradients never reached the adapter, or the merge never folded the adapter into the base, so the extractor embedded the unmodified base model.
#
# Run one stage at a time.
#
# - **Stage 1** — did the adapter weights move at all? (needs the adapter on Drive; seconds, CPU) → *result: yes, all lora_B non-zero.*
# - **Stage 2** — does merging fold that update into the base weights? (re-downloads the base; a few min, CPU) → *result: yes, ~8% relative change in the query weights.*
# - **Stage 3** — faithful real-cell reproduction: embed a real sample through base vs merged and triangulate against the saved zero-shot baseline, to decide genuine-null vs a merge/wiring failure. Heavier (re-stands-up the Geneformer env); run in a fresh GPU runtime. → *result: confirmed real null — base-vs-merged drift 0.0056 on a fresh 2,000-cell sample, matching §7a's original 0.0057.*

# %% [markdown]
# ### 1a — locate the saved adapter
#
# Mount Drive and list the LoRA adapter colab_11 §6a saved after training, to confirm the artifact this whole diagnostic depends on actually exists before testing anything about it.

# %%
# Colab preinstalls torchao 0.10.0; PEFT's is_torchao_available() hard-raises
# below its 0.16.0 floor even though nothing here uses it -- remove it (same fix as colab_11 setup).
# !pip uninstall -y torchao -q

from google.colab import drive
drive.mount('/content/drive')

ADAPTER_DIR = '/content/drive/MyDrive/ad-glia-fm-prep/geneformer/cpt_aggregated_seed0_adapter'

import os
print('adapter dir contents:')
for f in sorted(os.listdir(ADAPTER_DIR)):
    print(' ', f, os.path.getsize(os.path.join(ADAPTER_DIR, f)), 'bytes')
# Out:
# WARNING: Skipping torchao as it is not installed.
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# adapter dir contents:
#   README.md 5200 bytes
#   adapter_config.json 1057 bytes
#   adapter_model.safetensors 1779464 bytes

# %% [markdown]
# > **Interpretation — adapter located (1a).** The directory holds exactly what a LoRA-only save should produce: a ~1.7 MB `adapter_model.safetensors`, its `adapter_config.json`, and an auto-generated `README.md` — no full 104M-parameter base weights (those are re-downloaded separately in Stage 2/3). This only confirms the artifact survived; whether training actually moved it is Stage 1's real test, next.

# %% [markdown]
# ## Stage 1 — did the adapter weights move?
#
# PEFT initializes LoRA's `B` matrix to exact zero, so at step 0 the adapter has literally no effect. If `lora_B` is still ~0 after training, gradients never reached it (frozen `requires_grad`, optimizer not stepping, etc.) — a mechanical failure, and the drift result is meaningless. If `lora_B` norms are clearly non-zero, training moved the adapter and we proceed to Stage 2.

# %%
from safetensors.torch import load_file

sd = load_file(os.path.join(ADAPTER_DIR, 'adapter_model.safetensors'))

b_norms = []
for name, t in sd.items():
    tag = ''
    if 'lora_B' in name:
        b_norms.append(t.norm().item())
        tag = '  <- B (zero at init)'
    print(f'{name:70s} shape={str(tuple(t.shape)):14s} norm={t.norm().item():.6f} mean_abs={t.abs().mean().item():.6e}{tag}')

print()
if b_norms:
    import numpy as np
    b = np.array(b_norms)
    print(f'lora_B tensors: {len(b)} | norm min={b.min():.6f} median={np.median(b):.6f} max={b.max():.6f}')
    print('VERDICT:', 'B moved -> gradients flowed, go to Stage 2' if b.min() > 1e-6 else 'B still ~0 -> gradients never reached adapter (mechanical failure)')
else:
    print('no lora_B tensors found -- check adapter naming')
# Out:
# base_model.model.bert.encoder.layer.0.attention.self.key.lora_A.weight shape=(8, 768)       norm=2.349117 mean_abs=2.434665e-02
# base_model.model.bert.encoder.layer.0.attention.self.key.lora_B.weight shape=(768, 8)       norm=1.167698 mean_abs=1.175768e-02  <- B (zero at init)
# base_model.model.bert.encoder.layer.0.attention.self.query.lora_A.weight shape=(8, 768)       norm=2.361115 mean_abs=2.434684e-02
# base_model.model.bert.encoder.layer.0.attention.self.query.lora_B.weight shape=(768, 8)       norm=1.278809 mean_abs=1.292904e-02  <- B (zero at init)
# base_model.model.bert.encoder.layer.0.attention.self.value.lora_A.weight shape=(8, 768)       norm=2.744854 mean_abs=2.807954e-02
# base_model.model.bert.encoder.layer.0.attention.self.value.lora_B.weight shape=(768, 8)       norm=0.992579 mean_abs=8.845972e-03  <- B (zero at init)
# base_model.model.bert.encoder.layer.1.attention.self.key.lora_A.weight shape=(8, 768)       norm=1.962265 mean_abs=2.067357e-02
# base_model.model.bert.encoder.layer.1.attention.self.key.lora_B.weight shape=(768, 8)       norm=0.924370 mean_abs=9.082078e-03  <- B (zero at init)
# base_model.model.bert.encoder.layer.1.attention.self.query.lora_A.weight shape=(8, 768)       norm=2.166261 mean_abs=2.237523e-02
# base_model.model.bert.encoder.layer.1.attention.self.query.lora_B.weight shape=(768, 8)       norm=1.128003 mean_abs=1.112299e-02  <- B (zero at init)
# base_model.model.bert.encoder.layer.1.attention.self.value.lora_A.weight shape=(8, 768)       norm=2.233632 mean_abs=2.325158e-02
# base_model.model.bert.encoder.layer.1.attention.self.value.lora_B.weight shape=(768, 8)       norm=0.830586 mean_abs=8.130724e-03  <- B (zero at init)
# base_model.model.bert.encoder.layer.10.attention.self.key.lora_A.weight shape=(8, 768)       norm=2.172517 mean_abs=2.261282e-02
# base_model.model.bert.encoder.layer.10.attention.self.key.lora_B.weight shape=(768, 8)       norm=1.250701 mean_abs=1.232031e-02  <- B (zero at init)
# base_model.model.bert.encoder.layer.10.attention.self.query.lora_A.weight shape=(8, 768)       norm=2.408213 mean_abs=2.461177e-02
# base_model.model.bert.encoder.layer.10.attention.self.query.lora_B.weight shape=(768, 8)       norm=1.273616 mean_abs=1.229628e-02  <- B (zero at init)
# base_model.model.bert.encoder.layer.10.attention.self.value.lora_A.weight shape=(8, 768)       norm=2.779997 mean_abs=2.858284e-02
# base_model.model.bert.encoder.layer.10.attention.self.value.lora_B.weight shape=(768, 8)       norm=1.175297 mean_abs=1.169922e-02  <- B (zero at init)
# base_model.model.bert.encoder.layer.11.attention.self.key.lora_A.weight shape=(8, 768)       norm=2.263275 mean_abs=2.348764e-02
# base_model.model.bert.encoder.layer.11.attention.self.key.lora_B.weight shape=(768, 8)       norm=1.363500 mean_abs=1.316301e-02  <- B (zero at init)
# base_model.model.bert.encoder.layer.11.attention.self.query.lora_A.weight shape=(8, 768)       norm=2.537894 mean_abs=2.593843e-02
# base_model.model.bert.encoder.layer.11.attention.self.query.lora_B.weight shape=(768, 8)       norm=1.099983 mean_abs=1.051935e-02  <- B (zero at init)
# base_model.model.bert.encoder.layer.11.attention.self.value.lora_A.weight shape=(8, 768)       norm=2.665495 mean_abs=2.742348e-02
# base_model.model.bert.encoder.layer.11.attention.self.value.lora_B.weight shape=(768, 8)       norm=1.175024 mean_abs=1.181279e-02  <- B (zero at init)
# base_model.model.bert.encoder.layer.2.attention.self.key.lora_A.weight shape=(8, 768)       norm=1.924063 mean_abs=2.034476e-02
# base_model.model.bert.encoder.layer.2.attention.self.key.lora_B.weight shape=(768, 8)       norm=0.887129 mean_abs=8.865410e-03  <- B (zero at init)
# base_model.model.bert.encoder.layer.2.attention.self.query.lora_A.weight shape=(8, 768)       norm=1.953209 mean_abs=2.040560e-02
# base_model.model.bert.encoder.layer.2.attention.self.query.lora_B.weight shape=(768, 8)       norm=0.941043 mean_abs=9.388997e-03  <- B (zero at init)
# base_model.model.bert.encoder.layer.2.attention.self.value.lora_A.weight shape=(8, 768)       norm=2.099539 mean_abs=2.205413e-02
# base_model.model.bert.encoder.layer.2.attention.self.value.lora_B.weight shape=(768, 8)       norm=0.857099 mean_abs=8.606604e-03  <- B (zero at init)
# base_model.model.bert.encoder.layer.3.attention.self.key.lora_A.weight shape=(8, 768)       norm=1.979061 mean_abs=2.076350e-02
# base_model.model.bert.encoder.layer.3.attention.self.key.lora_B.weight shape=(768, 8)       norm=0.893175 mean_abs=8.977332e-03  <- B (zero at init)
# base_model.model.bert.encoder.layer.3.attention.self.query.lora_A.weight shape=(8, 768)       norm=2.117965 mean_abs=2.212881e-02
# base_model.model.bert.encoder.layer.3.attention.self.query.lora_B.weight shape=(768, 8)       norm=1.049826 mean_abs=1.060714e-02  <- B (zero at init)
# base_model.model.bert.encoder.layer.3.attention.self.value.lora_A.weight shape=(8, 768)       norm=2.089498 mean_abs=2.176182e-02
# base_model.model.bert.encoder.layer.3.attention.self.value.lora_B.weight shape=(768, 8)       norm=0.882965 mean_abs=8.842290e-03  <- B (zero at init)
# base_model.model.bert.encoder.layer.4.attention.self.key.lora_A.weight shape=(8, 768)       norm=2.000736 mean_abs=2.113920e-02
# base_model.model.bert.encoder.layer.4.attention.self.key.lora_B.weight shape=(768, 8)       norm=0.951960 mean_abs=9.461223e-03  <- B (zero at init)
# base_model.model.bert.encoder.layer.4.attention.self.query.lora_A.weight shape=(8, 768)       norm=2.075500 mean_abs=2.166045e-02
# base_model.model.bert.encoder.layer.4.attention.self.query.lora_B.weight shape=(768, 8)       norm=1.061738 mean_abs=1.071437e-02  <- B (zero at init)
# base_model.model.bert.encoder.layer.4.attention.self.value.lora_A.weight shape=(8, 768)       norm=2.095334 mean_abs=2.199577e-02
# base_model.model.bert.encoder.layer.4.attention.self.value.lora_B.weight shape=(768, 8)       norm=0.929540 mean_abs=9.316211e-03  <- B (zero at init)
# base_model.model.bert.encoder.layer.5.attention.self.key.lora_A.weight shape=(8, 768)       norm=2.055643 mean_abs=2.155970e-02
# base_model.model.bert.encoder.layer.5.attention.self.key.lora_B.weight shape=(768, 8)       norm=0.967506 mean_abs=9.635713e-03  <- B (zero at init)
# base_model.model.bert.encoder.layer.5.attention.self.query.lora_A.weight shape=(8, 768)       norm=1.959684 mean_abs=2.054018e-02
# base_model.model.bert.encoder.layer.5.attention.self.query.lora_B.weight shape=(768, 8)       norm=0.991944 mean_abs=9.933225e-03  <- B (zero at init)
# base_model.model.bert.encoder.layer.5.attention.self.value.lora_A.weight shape=(8, 768)       norm=2.030805 mean_abs=2.136630e-02
# base_model.model.bert.encoder.layer.5.attention.self.value.lora_B.weight shape=(768, 8)       norm=0.896897 mean_abs=9.078976e-03  <- B (zero at init)
# base_model.model.bert.encoder.layer.6.attention.self.key.lora_A.weight shape=(8, 768)       norm=2.011908 mean_abs=2.119445e-02
# base_model.model.bert.encoder.layer.6.attention.self.key.lora_B.weight shape=(768, 8)       norm=0.950325 mean_abs=9.473574e-03  <- B (zero at init)
# base_model.model.bert.encoder.layer.6.attention.self.query.lora_A.weight shape=(8, 768)       norm=2.105816 mean_abs=2.188238e-02
# base_model.model.bert.encoder.layer.6.attention.self.query.lora_B.weight shape=(768, 8)       norm=1.075732 mean_abs=1.082347e-02  <- B (zero at init)
# base_model.model.bert.encoder.layer.6.attention.self.value.lora_A.weight shape=(8, 768)       norm=2.065520 mean_abs=2.164041e-02
# base_model.model.bert.encoder.layer.6.attention.self.value.lora_B.weight shape=(768, 8)       norm=0.849765 mean_abs=8.579500e-03  <- B (zero at init)
# base_model.model.bert.encoder.layer.7.attention.self.key.lora_A.weight shape=(8, 768)       norm=2.015164 mean_abs=2.112361e-02
# base_model.model.bert.encoder.layer.7.attention.self.key.lora_B.weight shape=(768, 8)       norm=0.965651 mean_abs=9.676699e-03  <- B (zero at init)
# base_model.model.bert.encoder.layer.7.attention.self.query.lora_A.weight shape=(8, 768)       norm=2.058586 mean_abs=2.154636e-02
# base_model.model.bert.encoder.layer.7.attention.self.query.lora_B.weight shape=(768, 8)       norm=1.055975 mean_abs=1.056701e-02  <- B (zero at init)
# base_model.model.bert.encoder.layer.7.attention.self.value.lora_A.weight shape=(8, 768)       norm=2.063615 mean_abs=2.140078e-02
# base_model.model.bert.encoder.layer.7.attention.self.value.lora_B.weight shape=(768, 8)       norm=0.864677 mean_abs=8.718321e-03  <- B (zero at init)
# base_model.model.bert.encoder.layer.8.attention.self.key.lora_A.weight shape=(8, 768)       norm=2.060249 mean_abs=2.156706e-02
# base_model.model.bert.encoder.layer.8.attention.self.key.lora_B.weight shape=(768, 8)       norm=0.983103 mean_abs=9.849469e-03  <- B (zero at init)
# base_model.model.bert.encoder.layer.8.attention.self.query.lora_A.weight shape=(8, 768)       norm=2.110236 mean_abs=2.191286e-02
# base_model.model.bert.encoder.layer.8.attention.self.query.lora_B.weight shape=(768, 8)       norm=1.058923 mean_abs=1.052783e-02  <- B (zero at init)
# base_model.model.bert.encoder.layer.8.attention.self.value.lora_A.weight shape=(8, 768)       norm=2.534374 mean_abs=2.584384e-02
# base_model.model.bert.encoder.layer.8.attention.self.value.lora_B.weight shape=(768, 8)       norm=0.988516 mean_abs=9.795095e-03  <- B (zero at init)
# base_model.model.bert.encoder.layer.9.attention.self.key.lora_A.weight shape=(8, 768)       norm=2.090534 mean_abs=2.155660e-02
# base_model.model.bert.encoder.layer.9.attention.self.key.lora_B.weight shape=(768, 8)       norm=1.138507 mean_abs=1.126884e-02  <- B (zero at init)
# base_model.model.bert.encoder.layer.9.attention.self.query.lora_A.weight shape=(8, 768)       norm=2.520932 mean_abs=2.589501e-02
# base_model.model.bert.encoder.layer.9.attention.self.query.lora_B.weight shape=(768, 8)       norm=1.301521 mean_abs=1.267410e-02  <- B (zero at init)
# base_model.model.bert.encoder.layer.9.attention.self.value.lora_A.weight shape=(8, 768)       norm=2.891041 mean_abs=2.966303e-02
# base_model.model.bert.encoder.layer.9.attention.self.value.lora_B.weight shape=(768, 8)       norm=1.162173 mean_abs=1.159435e-02  <- B (zero at init)
#
# lora_B tensors: 36 | norm min=0.830586 median=0.992262 max=1.363500
# VERDICT: B moved -> gradients flowed, go to Stage 2

# %% [markdown]
# > **Interpretation — adapter weights moved, gradients flowed (1b).** All 36 `lora_B` tensors (query/key/value × 12 transformer layers) came back with norm 0.83–1.36 (median 0.99) — PEFT initializes `lora_B` to exact zero, so any of these being non-zero means gradients reached the adapter and the optimizer stepped. This rules out the most basic mechanical failure (frozen `requires_grad`, dead optimizer, etc.). It does not yet say whether that update *survives* being folded back into the base model — that's Stage 2.

# %% [markdown]
# ## Stage 2 — does merging fold the update into the base weights?
#
# Re-download the exact base recorded in `adapter_config.json`, snapshot a couple of attention-projection weights, apply the adapter, `merge_and_unload()`, and diff. This reproduces colab_11 §6a's merge step. If the merged weights differ from the base by a real (if small) relative amount, the merge mechanism is sound and #3 is ruled out — leaving the genuine-null vs undertrained call. If the delta is exactly 0, the merge is a no-op and the extractor was embedding the base model.

# %%
import json, torch
from transformers import BertForMaskedLM
from peft import PeftModel

cfg = json.load(open(os.path.join(ADAPTER_DIR, 'adapter_config.json')))
base_path = cfg['base_model_name_or_path']
print('base_model_name_or_path:', base_path)
print('target_modules:', cfg.get('target_modules'), '| r:', cfg.get('r'), '| alpha:', cfg.get('lora_alpha'))

# The adapter records the base as a local path from colab_11's (now-gone) runtime.
# Re-fetch just the V2-104M weights to that exact path at colab_11's pinned commit.
if not os.path.exists(os.path.join(base_path, 'config.json')):
    from huggingface_hub import snapshot_download
    snapshot_download(repo_id='ctheodoris/Geneformer',
                      revision='04c2b2e84da7c0f385c3f9ad8f3ec24bab6650e5',
                      allow_patterns=['Geneformer-V2-104M/*'],
                      local_dir='/content/Geneformer')
    print('base model fetched ->', base_path)
else:
    print('base model already present ->', base_path)

base = BertForMaskedLM.from_pretrained(base_path)

# snapshot a few targeted weights BEFORE merge
watch = [n for n, _ in base.named_parameters()
         if n.endswith('attention.self.query.weight')][:2]
before = {n: base.state_dict()[n].detach().clone() for n in watch}

peft_model = PeftModel.from_pretrained(base, ADAPTER_DIR)
merged = peft_model.merge_and_unload()
msd = merged.state_dict()

print()
for n in watch:
    d = (msd[n] - before[n]).norm().item()
    bn = before[n].norm().item()
    print(f'{n}\n   base_norm={bn:.4f}  delta_norm={d:.6f}  rel_delta={d/bn:.6e}')

any_move = any((msd[n] - before[n]).norm().item() > 0 for n in watch)
print()
print('VERDICT:', 'merge folds the adapter in -> #3 ruled out' if any_move else 'merge is a no-op -> extractor embedded the base model')
# Out:
# base_model_name_or_path: /content/Geneformer/Geneformer-V2-104M
# target_modules: ['value', 'key', 'query'] | r: 8 | alpha: 16
# base model already present -> /content/Geneformer/Geneformer-V2-104M
#
# bert.encoder.layer.0.attention.self.query.weight
#    base_norm=27.7667  delta_norm=2.411541  rel_delta=8.685026e-02
# bert.encoder.layer.1.attention.self.query.weight
#    base_norm=27.5406  delta_norm=2.058597  rel_delta=7.474777e-02
#
# VERDICT: merge folds the adapter in -> #3 ruled out

# %% [markdown]
# > **Interpretation — merge folds a real, non-trivial weight change into the base (2a).** Re-downloading the exact pinned base checkpoint and merging the adapter shifted the two watched query-projection weight matrices by 7.5–8.7% relative to their base norm (layer 0: base 27.77, Δ2.41 → 8.7%; layer 1: base 27.54, Δ2.06 → 7.5%) — an order of magnitude above the exact-zero delta a no-op merge would produce. This directly rules out explanation #3 (silent merge failure): `merge_and_unload()` is doing real, substantial work. It does not yet say whether an ~8% weight change on two matrices survives being pooled across 12 layers into a single 768-dim cell embedding — that's what Stage 3 tests on real cells.

# %% [markdown]
# ## Stage 3 — faithful real-cell reproduction (base vs merged embedding)
#
# Stages 1–2 showed the adapter learned and the merge folds a ~8% weight change into the base, so a silent merge failure is unlikely — but that alone does not prove colab_11 §6a embedded the *merged* checkpoint rather than the base, nor whether 0.0057 sits above the run-to-run noise floor. This stage settles both by reproducing §3a→§6a→§7a on a small real sample and embedding it through **both** the base and the re-merged model, then triangulating against the saved colab_09 zero-shot baseline.
#
# **Run this in a FRESH runtime** (Runtime → Restart session): it re-stands-up colab_11's Geneformer environment. Same numpy-restart dance as colab_11 §1a — after the setup cell installs, restart once, re-run setup (fast the second time), then continue downward. A **GPU + high-RAM** runtime is recommended (EmbExtractor + subset loading). Stages 1–2 above do **not** need to be re-run for this.
#
# Readouts:
#
# - **base-vs-merged drift ≈ 0.005** → the merged model genuinely shifts the pooled embedding by that much → §6a used it → INERT is a *real* null (config too weak, not a bug).
# - **base-vs-merged drift ≈ 0** → the 8% weight change washes out of the pooled embedding → §7a's 0.0057 was base-vs-base noise → wiring/void.
# - **merged-vs-saved-zeroshot** should reproduce §7a's ~0.0056 if §6a used the merged model; **base-vs-saved-zeroshot ≈ 0** confirms a faithful reproduction and a low cross-session noise floor.

# %% [markdown]
# A stale `/content/Geneformer` directory from an earlier attempt in this session survived a Runtime → Restart session (which resets the kernel, not the VM's `/content` disk) — the setup cell's `os.path.exists` check saw it and skipped the clone, so `pip install .` failed on an incomplete checkout. Clear it before rerunning setup.

# %%
# !rm -rf /content/Geneformer

# %%
# --- Stage 3 setup — re-stand-up colab_11's Geneformer environment (mirrors colab_11 §1a) ---
import os, subprocess
from google.colab import drive
drive.mount("/content/drive")

REPO_PATH = "/content/ad-glia-fm-prep"
if not os.path.exists(REPO_PATH):
    subprocess.run(["git", "clone", "https://github.com/pavlemic/ad-glia-fm-prep.git", REPO_PATH], check=True)
# !pip install -q -r {REPO_PATH}/requirements_geneformer.txt

GENEFORMER_REPO = "/content/Geneformer"
GF_COMMIT = "04c2b2e84da7c0f385c3f9ad8f3ec24bab6650e5"   # colab_11's pinned geneformer_commit
if not os.path.exists(GENEFORMER_REPO):
    # !git lfs install
    # !git clone https://huggingface.co/ctheodoris/Geneformer {GENEFORMER_REPO}
    # !git -C {GENEFORMER_REPO} checkout {GF_COMMIT}
# !cd {GENEFORMER_REPO} && pip install -q .

# torchao 0.10.0 is preinstalled and unused; PEFT's is_torchao_available() hard-raises below 0.16.0.
# !pip uninstall -y torchao -q

import torch
print("GPU:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU only (slower embed)")
print("SETUP DONE -- if this cell upgraded numpy, Runtime>Restart session, re-run this cell, then continue.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#   Preparing metadata (setup.py) ... done
#   Building wheel for geneformer (setup.py) ... done
# WARNING: Skipping torchao as it is not installed.
# GPU: NVIDIA A100-SXM4-80GB
# SETUP DONE -- if this cell upgraded numpy, Runtime>Restart session, re-run this cell, then continue.

# %% [markdown]
# ### Stage 3 setup — restart note
#
# If the setup cell above upgraded numpy, **Runtime → Restart session now**, then re-run the setup cell (idempotent and fast the second time) and continue downward. This is the same stale-numpy issue colab_11 §1a documents (Colab's kernel loads numpy before the install overwrites it on disk).

# %% [markdown]
# > **Interpretation — environment ready (3a).** After clearing the stale `/content/Geneformer` directory, GPU allocated (A100-SXM4-80GB), Geneformer rebuilt cleanly from the pinned commit, and the stray `torchao` package was already absent this run (its uninstall warning is harmless — it only matters if present). Ready to reproduce the embedding pipeline on real cells.

# %% [markdown]
# ### 3.3 — sample real cells with colab_11's exact indexing, map to Ensembl IDs
#
# Rebuild colab_11 §3a's `cell_index` scheme (global index over `concat([micro, astro])`) via backed reads so a random sample lines up cell-for-cell with the saved zero-shot baseline, then reproduce §3a's raw-counts guard and §4a's symbol→Ensembl mapping (APOE hard-fail gate included).

# %%
# --- Stage 3.3 — load a real sample with colab_11's exact cell_index, map Ensembl IDs (§3a + §4a) ---
import os, pickle
import numpy as np, pandas as pd, anndata as ad
import scipy.sparse as sp

DRIVE_ROOT = "/content/drive/MyDrive/ad-glia-fm-prep"
MICRO_PATH = os.path.join(DRIVE_ROOT, "micro_subset", "micro_subset.h5ad")
ASTRO_PATH = os.path.join(DRIVE_ROOT, "astro_subset", "astro_subset.h5ad")
N_SAMPLE, SAMPLE_SEED = 2000, 0

# colab_11 §3a builds cell_index = arange over concat([micro, astro]): the first n_micro global
# indices are micro rows (in file order), the rest are astro rows. Reproduce that mapping exactly
# via backed reads so a sampled cell_index lines up with the saved zero-shot baseline. To SLICE the
# astro file we need LOCAL row positions (global - n_micro); the stored cell_index stays GLOBAL.
mb = ad.read_h5ad(MICRO_PATH, backed="r")
ab = ad.read_h5ad(ASTRO_PATH, backed="r")
assert list(mb.var_names) == list(ab.var_names), "gene panels differ between subsets"
n_micro, n_astro = mb.n_obs, ab.n_obs
N = n_micro + n_astro
print("n_micro", n_micro, "| n_astro", n_astro, "| total", N)

rng = np.random.default_rng(SAMPLE_SEED)
g = np.sort(rng.choice(N, size=N_SAMPLE, replace=False))       # global cell_index values
g_micro, g_astro = g[g < n_micro], g[g >= n_micro]

parts = []
if len(g_micro):
    m = mb[g_micro].to_memory()                # micro global index == micro local position
    m.obs = m.obs.copy(); m.obs["cell_index"] = g_micro
    parts.append(m)
if len(g_astro):
    a = ab[g_astro - n_micro].to_memory()      # slice by LOCAL astro position
    a.obs = a.obs.copy(); a.obs["cell_index"] = g_astro   # keep GLOBAL cell_index
    parts.append(a)
samp = ad.concat(parts, join="inner")
samp.obs["cell_index"] = samp.obs["cell_index"].astype(int)
print("sample:", samp.shape)

# raw-counts guard (colab_11 §3a)
data = samp.X.data if sp.issparse(samp.X) else np.asarray(samp.X).ravel()
frac_int = float(np.mean(np.mod(data, 1) == 0)) if data.size else 1.0
assert frac_int >= 0.99, f".X is not raw counts (int frac {frac_int:.3f})"
print("raw-counts int-frac:", round(frac_int, 3))

# §4a: map gene symbols -> Ensembl IDs with Geneformer's own dictionaries; APOE must be tokenizable
from geneformer import ENSEMBL_DICTIONARY_FILE, TOKEN_DICTIONARY_FILE
with open(ENSEMBL_DICTIONARY_FILE, "rb") as f: symbol_to_ensembl = pickle.load(f)
with open(TOKEN_DICTIONARY_FILE, "rb") as f: token_dictionary = pickle.load(f)
samp.var["ensembl_id"] = [symbol_to_ensembl.get(s) for s in samp.var_names]
assert symbol_to_ensembl.get("APOE") in token_dictionary, "APOE not tokenizable -- vocab mismatch"
print("APOE tokenizable: OK |", int(samp.var['ensembl_id'].map(lambda e: e in token_dictionary if e else False).sum()), "genes in vocab")
# Out:
# n_micro 54805 | n_astro 87783 | total 142588
# sample: (2000, 26514)
# raw-counts int-frac: 1.0
# APOE tokenizable: OK | 16792 genes in vocab

# %% [markdown]
# > **Interpretation — substrate and vocab match colab_11 exactly (3.3).** `n_micro`/`n_astro`/total (54,805 / 87,783 / 142,588) reproduce colab_11 §3a's substrate size exactly, confirming this diagnostic is sampling from the identical cell population, not a stale or mismatched copy. The 2,000-cell sample is 100% raw integer counts (guard passed) and 16,792/26,514 genes map into Geneformer's vocab (63.3%, APOE included) — matching §4a's original coverage number to the cell. Nothing here yet touches the model; this only certifies the input is faithful.

# %% [markdown]
# ### 3.4 — tokenize the sample
#
# Reproduce colab_11 §4b exactly, including the same upstream Geneformer bug patch (`sum_ensembl_ids` resets `var.index` to gene symbols/Ensembl IDs when `TranscriptomeTokenizer` expects integer positions — patched to a plain `RangeIndex`, same fix as §4b).

# %%
# --- Stage 3.4 — tokenize the sample (reproduces colab_11 §4b, incl. the sum_ensembl_ids patch) ---
from geneformer import TranscriptomeTokenizer
import geneformer.tokenizer as _gftok

samp.obs["n_counts"] = np.asarray(samp.X.sum(axis=1)).ravel()
assert (samp.obs["n_counts"] > 0).all(), "zero-count cells present"

TOK_IN, TOK_OUT = "/content/diag_tok_in", "/content/diag_tok_out"
os.makedirs(TOK_IN, exist_ok=True)
os.makedirs(TOK_OUT, exist_ok=True)
samp.write_h5ad(os.path.join(TOK_IN, "samp.h5ad"))

# same upstream-bug patch colab_11 §4b applies: reset var index to RangeIndex after sum_ensembl_ids
_orig_sum = _gftok.sum_ensembl_ids
def _sum_patch(*a, **k):
    r = _orig_sum(*a, **k)
    r.var.index = pd.RangeIndex(r.n_vars)
    return r
_gftok.sum_ensembl_ids = _sum_patch

tk = TranscriptomeTokenizer({"cell_index": "cell_index"}, nproc=4)   # defaults = V2 / GC104M, as §4b
tk.tokenize_data(TOK_IN, TOK_OUT, "diag", file_format="h5ad")
TOK_DS = os.path.join(TOK_OUT, "diag.dataset")
print("tokenized ->", TOK_DS)
# Out:
# Tokenizing /content/diag_tok_in/samp.h5ad
# /content/diag_tok_in/samp.h5ad has no column attribute 'filter_pass'; tokenizing all cells.
# Creating dataset.
# tokenized -> /content/diag_tok_out/diag.dataset

# %% [markdown]
# > **Interpretation — tokenization reproduces §4b cleanly (3.4).** The `sum_ensembl_ids` patch prevented the same `KeyError` colab_11 §4b hit live, and tokenization completed without incident. The "no column attribute filter_pass" notice is Geneformer's own harmless default (tokenize all cells when no QC column is present) — expected here since this sample was drawn directly from the already-QC'd subset files, not re-filtered.

# %% [markdown]
# ### 3.5 — rebuild the merged checkpoint and embed the sample through base and merged
#
# Reproduce colab_11 §6a: merge the adapter into a freshly re-downloaded base checkpoint, save it standalone, then run `EmbExtractor` over the tokenized sample through **both** the untouched base and the re-merged checkpoint, so the two embeddings are directly comparable cell-for-cell.

# %%
# --- Stage 3.5 — rebuild the merged checkpoint (as §6a did) and embed the sample through base + merged ---
import torch
from transformers import BertForMaskedLM
from peft import PeftModel
from geneformer import EmbExtractor

ADAPTER_DIR = "/content/drive/MyDrive/ad-glia-fm-prep/geneformer/cpt_aggregated_seed0_adapter"
MODEL_DIR   = "/content/Geneformer/Geneformer-V2-104M"      # from the LFS clone in setup
assert os.path.exists(MODEL_DIR), f"base model dir missing: {MODEL_DIR}"

# reproduce §6a: merge the adapter into the base, write a standalone checkpoint
base = BertForMaskedLM.from_pretrained(MODEL_DIR)
merged = PeftModel.from_pretrained(base, ADAPTER_DIR).merge_and_unload()
MERGED_DIR = "/content/diag_merged"
merged.save_pretrained(MERGED_DIR)
merged.config.to_json_file(os.path.join(MERGED_DIR, "config.json"))
print("rebuilt merged checkpoint ->", MERGED_DIR)

def _embed(model_dir, name):
    ee = EmbExtractor(model_type="Pretrained", num_classes=0, emb_mode="cell",
                      max_ncells=None, emb_layer=-1, emb_label=["cell_index"],
                      forward_batch_size=64, nproc=4)
    out = f"/content/diag_emb_{name}"
    os.makedirs(out, exist_ok=True)
    return ee.extract_embs(model_dir, TOK_DS, out, name)

df_base   = _embed(MODEL_DIR,  "base")     # same weights colab_09 embedded
df_merged = _embed(MERGED_DIR, "merged")   # the post-CPT checkpoint §6a should have used
print("base emb:", df_base.shape, "| merged emb:", df_merged.shape)
# Out:
# rebuilt merged checkpoint -> /content/diag_merged
# /usr/local/lib/python3.12/dist-packages/pyarrow/compute.py:230: FutureWarning: Specifying null_placement in SortOptions is deprecated as of 25.0.0. Specify null_placement per sort_key instead.
#   return options_class(*args, **kwargs)
# WARNING:geneformer.emb_extractor:CLS token present in token dictionary, excluding from average.
# WARNING:geneformer.emb_extractor:EOS token present in token dictionary, excluding from average.
#   0%|          | 0/32 [00:00<?, ?it/s]
# WARNING:geneformer.emb_extractor:CLS token present in token dictionary, excluding from average.
# WARNING:geneformer.emb_extractor:EOS token present in token dictionary, excluding from average.
#   0%|          | 0/32 [00:00<?, ?it/s]
# base emb: (2000, 769) | merged emb: (2000, 769)

# %% [markdown]
# > **Interpretation — both embeddings extracted successfully (3.5).** Base and merged models each produced a (2000, 769)-shape output (768-dim embedding + `cell_index` column), ca. 1.5 minutes each on the A100 — consistent throughput with §6a's full-dataset extraction, just scaled to 2,000 cells. The CLS/EOS-excluded-from-average warnings are Geneformer's own standard notice, not an error. Both checkpoints are now embedded on the identical sample; Stage 3.6 compares them directly.

# %% [markdown]
# ### 3.6 — compare base vs merged, triangulate against the saved zero-shot baseline
#
# Compute the same per-cell cosine drift metric as colab_11 §7a directly between the two fresh embeddings, then cross-check both against colab_09's saved zero-shot baseline to establish the reproduction pipeline's own noise floor.

# %%
# --- Stage 3.6 — compare (base vs merged) and triangulate against the saved zero-shot baseline ---
import numpy as np, pandas as pd, scanpy as sc

def _to_X(df):
    cols = [c for c in df.columns if c != "cell_index"]
    return df.set_index("cell_index")[cols].astype(np.float32)

Xb = _to_X(df_base)
Xm = _to_X(df_merged)
common = Xb.index.intersection(Xm.index)
Xb_c = Xb.loc[common].to_numpy()
Xm_c = Xm.loc[common].to_numpy()

def _per_cell_cos(A, B):                       # identical to colab_11 §7a
    num = (A * B).sum(1)
    den = np.linalg.norm(A, axis=1) * np.linalg.norm(B, axis=1) + 1e-12
    return num / den

drift_bm = 1.0 - float(np.median(_per_cell_cos(Xb_c, Xm_c)))
print(f"base vs merged drift (sample, n={len(common)}): {drift_bm:.4f}")

# triangulate against colab_09's saved zero-shot baseline (the vectors §7a diffed against)
ZS_PATH = "/content/drive/MyDrive/ad-glia-fm-prep/geneformer/glia_geneformer_zeroshot.h5ad"
zs = sc.read_h5ad(ZS_PATH)
zs_df = pd.DataFrame(np.asarray(zs.X), index=zs.obs["cell_index"].values).astype(np.float32)
zs_s = zs_df.reindex(common)
if zs_s.notna().all(axis=1).all():
    Xz = zs_s.to_numpy()
    drift_bz = 1.0 - float(np.median(_per_cell_cos(Xb_c, Xz)))
    drift_mz = 1.0 - float(np.median(_per_cell_cos(Xm_c, Xz)))
    print(f"base   vs saved-zeroshot drift: {drift_bz:.4f}   (~0 => faithful base reproduction / low cross-session noise floor)")
    print(f"merged vs saved-zeroshot drift: {drift_mz:.4f}   (should ~ 0.0056 from colab_11 §7a if that run used the merged model)")
else:
    print("some sample cell_index absent from saved zero-shot -- skipping triangulation")

print("\nREADING:")
print(f"  base-vs-merged = {drift_bm:.4f}")
print("  ~0.005 -> merged genuinely shifts the pooled embedding; §6a used it; INERT is a REAL null (config too weak, not a bug)")
print("  ~0     -> the 8% weight change washes out of the pooled embedding; §7a's 0.0057 was noise -> wiring/void")
# Out:
# base vs merged drift (sample, n=2000): 0.0056
# base   vs saved-zeroshot drift: 0.0000   (~0 => faithful base reproduction / low cross-session noise floor)
# merged vs saved-zeroshot drift: 0.0056   (should ~ 0.0056 from colab_11 §7a if that run used the merged model)
#
# READING:
#   base-vs-merged = 0.0056
#   ~0.005 -> merged genuinely shifts the pooled embedding; §6a used it; INERT is a REAL null (config too weak, not a bug)
#   ~0     -> the 8% weight change washes out of the pooled embedding; §7a's 0.0057 was noise -> wiring/void

# %% [markdown]
# > **Interpretation — CONFIRMED: colab_11's INERT result is a real null, not a wiring bug (3.6).** `base-vs-merged` drift on this fresh 2,000-cell sample is **0.0056** — matching colab_11 §7a's original held-out-test measurement of 0.0057 almost to the fourth decimal, despite being computed independently (different cells, different runtime, different session, re-downloaded base and re-merged adapter from scratch). `base-vs-saved-zeroshot` drift is **0.0000**: re-embedding the untouched base model through this rebuilt pipeline exactly reproduces colab_09's saved baseline, meaning the reproduction pipeline itself contributes ~zero spurious drift — the 0.0056 signal above it cannot be reproduction noise. `merged-vs-saved-zeroshot` (0.0056) matches `base-vs-merged` almost exactly, as expected since the base is essentially identical to the zero-shot baseline.
#
# This resolves all three candidate explanations from the top of this notebook: not mechanical failure (Stage 1), not a silent merge no-op (Stage 2), and now confirmed genuine rather than noise (Stage 3) — the moderate attention-only LoRA config (r=8 on query/key/value only, MLM head frozen, ~0.67 epoch) produces a small but real and reproducible ~6° pooled-embedding rotation that is an order of magnitude below the 0.05 registration gate. The correct next step is calibrating the LoRA configuration up — the FFN `dense` target-module lever colab_11 §5a explicitly held in reserve, and/or higher rank `r` or more training steps — and rerunning colab_11, not further pipeline debugging.
